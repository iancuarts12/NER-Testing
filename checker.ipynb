# %%
train_data = [
    # ----------- Shower Maintenance -----------

    # Clog removal
    ("Clog removal is necessary to maintain proper drainage in Manila.", 
     {"entities": [(0, 12, "SKILL"), (0, 12, "SERVICE"), (49, 55, "GPE")]}),

    ("Removal of clog is performed frequently in commercial kitchens by plumber John in Makati.", 
     {"entities": [(0, 15, "SKILL"), (64, 68, "PERSON"), (54, 61, "SPECIALIZATION"), (72, 78, "GPE")]}),

    ("Removal of clogs helps prevent plumbing emergencies in Quezon City.", 
     {"entities": [(0, 16, "SKILL"), (44, 57, "GPE")]}),

    ("Removing clog requires proper tools and careful handling.", 
     {"entities": [(0, 14, "SKILL")]}),

    ("Removing clogs is often handled by professional plumbers in Pasig.", 
     {"entities": [(0, 15, "SKILL"), (36, 44, "SPECIALIZATION"), (48, 53, "GPE")]}),

    ("Removing of clog was part of the routine maintenance.", 
     {"entities": [(0, 17, "SKILL")]}),

    ("Removing of clogs requires high-pressure equipment.", 
     {"entities": [(0, 18, "SKILL")]}),

    ("The plumber removed a clog from the kitchen sink in Taguig.", 
     {"entities": [(4, 10, "SPECIALIZATION"), (15, 28, "SKILL"), (51, 57, "GPE")]}),

    ("He removed a clogs quickly to restore drainage in Pasay.", 
     {"entities": [(0, 2, "PERSON"), (3, 18, "SKILL"), (36, 41, "GPE")]}),

    ("Removed clog was maintained by the maintenance team in Malabon.", 
     {"entities": [(0, 12, "SKILL"), (46, 53, "GPE")]}),

    ("The team removed clogs in multiple apartments yesterday in Navotas.", 
     {"entities": [(4, 8, "PERSON"), (9, 21, "SKILL"), (56, 63, "GPE")]}),

    # Showerhead repair
    ("Showerhead repair is necessary to fix leaks in bathrooms in Marikina.", 
     {"entities": [(0, 17, "SKILL"), (0, 17, "SERVICE"), (55, 63, "GPE")]}),

    ("Showerhead repairs are frequently performed by plumbers in Mandaluyong.", 
     {"entities": [(0, 18, "SKILL"), (37, 44, "SPECIALIZATION"), (48, 60, "GPE")]}),

    ("Repairing showerhead requires proper tools and skill in Valenzuela.", 
     {"entities": [(0, 20, "SKILL"), (53, 63, "GPE")]}),

    ("Repairing showerheads is part of routine bathroom maintenance in Muntinlupa.", 
     {"entities": [(0, 21, "SKILL"), (55, 66, "GPE")]}),

    ("Repairing of showerhead was scheduled for this morning by plumber Mike in Las Piñas.", 
     {"entities": [(0, 23, "SKILL"), (39, 45, "SPECIALIZATION"), (46, 50, "PERSON"), (54, 64, "GPE")]}),

    ("Repairing of showerheads helps prevent water leaks in Caloocan.", 
     {"entities": [(0, 24, "SKILL"), (44, 52, "GPE")]}),

    ("The plumber repaired a showerhead in the master bathroom in San Juan.", 
     {"entities": [(4, 10, "SPECIALIZATION"), (15, 31, "SKILL"), (54, 61, "GPE")]}),

    ("He repaired showerheads quickly to restore water flow in Pateros.", 
     {"entities": [(0, 2, "PERSON"), (3, 19, "SKILL"), (47, 54, "GPE")]}),

    # Valve replacement
    ("Valve replacement is needed to ensure proper water control in Taguig.", 
     {"entities": [(0, 16, "SKILL"), (49, 55, "GPE")]}),

    ("Valve replacements are commonly performed during plumbing upgrades by plumber Lisa in Makati.", 
     {"entities": [(0, 17, "SKILL"), (53, 59, "SPECIALIZATION"), (60, 64, "PERSON"), (68, 74, "GPE")]}),

    ("Replacing valve requires proper tools and attention to detail in Manila.", 
     {"entities": [(0, 16, "SKILL"), (54, 60, "GPE")]}),

    ("Replacing valves is part of routine bathroom maintenance in Parañaque.", 
     {"entities": [(0, 17, "SKILL"), (54, 64, "GPE")]}),

    ("Replacing of valve was scheduled for the morning in Quezon City.", 
     {"entities": [(0, 19, "SKILL"), (49, 61, "GPE")]}),

    ("Replacing of valves ensures smooth water operation in Pasig.", 
     {"entities": [(0, 20, "SKILL"), (47, 52, "GPE")]}),

    ("Replacement of valve is sometimes necessary after leaks in Malabon.", 
     {"entities": [(0, 19, "SKILL"), (53, 60, "GPE")]}),

    ("Replacement of valves helps maintain plumbing systems in Muntinlupa.", 
     {"entities": [(0, 20, "SKILL"), (52, 63, "GPE")]}),

    ("The plumber replaced a valve in the shower system in Marikina.", 
     {"entities": [(4, 10, "SPECIALIZATION"), (15, 28, "SKILL"), (57, 65, "GPE")]}),

    ("He replaced valves quickly to restore proper flow in Navotas.", 
     {"entities": [(0, 2, "PERSON"), (3, 16, "SKILL"), (47, 54, "GPE")]}),

    # Shower pipe repair
    ("Shower pipe repair is necessary to prevent water leaks in Pasay.", 
     {"entities": [(0, 19, "SKILL"), (41, 46, "GPE")]}),

    ("Shower pipe repairs are regularly performed in bathrooms in Valenzuela.", 
     {"entities": [(0, 20, "SKILL"), (52, 62, "GPE")]}),

    ("Repairing shower pipe requires high-quality tools by plumber Anna in Taguig.", 
     {"entities": [(0, 22, "SKILL"), (36, 42, "SPECIALIZATION"), (43, 47, "PERSON"), (51, 57, "GPE")]}),

    ("Repairing shower pipes is part of standard maintenance in Pateros.", 
     {"entities": [(0, 23, "SKILL"), (48, 55, "GPE")]}),

    ("Repairing of shower pipe was scheduled this morning in Las Piñas.", 
     {"entities": [(0, 25, "SKILL"), (45, 55, "GPE")]}),

    ("Repairing of shower pipes prevents water damage in San Juan.", 
     {"entities": [(0, 26, "SKILL"), (48, 55, "GPE")]}),

    ("The plumber repaired a shower pipe in the master bathroom in Caloocan.", 
     {"entities": [(4, 10, "SPECIALIZATION"), (15, 31, "SKILL"), (54, 62, "GPE")]}),

    ("He repaired shower pipes quickly to restore water flow in Makati.", 
     {"entities": [(0, 2, "PERSON"), (3, 19, "SKILL"), (47, 53, "GPE")]}),
]


def verify_entities(data):
    for i, (text, annotation) in enumerate(data):
        print(f"\nSentence {i+1}: {text}")
        entities = annotation.get("entities", [])
        if not entities:
            print("  No entities found.")
            continue
        for start, end, label in entities:
            detected_text = text[start:end]
            print(f"  Entity: '{detected_text}' | Label: {label} | Span: ({start}, {end})")
            # Optional: highlight in sentence
            highlight = text[:start] + "[" + text[start:end] + f"|{label}]" + text[end:]
            print(f"    Highlighted: {highlight}")

# Run verification
verify_entities(train_data)
# Out:
# Sentence 1: Drain cleaning is essential to prevent clogs and backups.
#   Entity: 'Drain cleaning ' | Label: SKILL | Span: (0, 15)
#     Highlighted: [Drain cleaning |SKILL]is essential to prevent clogs and backups.
#
# Sentence 2: Drain cleanings occur regularly in commercial properties.
#   Entity: 'Drain cleanings' | Label: SKILL | Span: (0, 15)
#     Highlighted: [Drain cleanings|SKILL] occur regularly in commercial properties.
#
# Sentence 3: Cleaning drain requires proper tools and careful handling.
#   Entity: 'Cleaning drain' | Label: SKILL | Span: (0, 14)
#     Highlighted: [Cleaning drain|SKILL] requires proper tools and careful handling.
#
# Sentence 4: Cleaning drains is often performed by professional plumbers.
#   Entity: 'Cleaning drains' | Label: SKILL | Span: (0, 15)
#     Highlighted: [Cleaning drains|SKILL] is often performed by professional plumbers.
#
# Sentence 5: Cleaning of drain takes priority after heavy rainfall.
# ...
