# %%
training_data = [

    # ----------- Toilet Maintenance -----------
    ("The plumber installs toilets in every new bathroom.", 
     {"entities": [(4, 11, "SPECIALIZATION"), (20, 36, "SERVICE"), (37, 44, "SKILLS")]}),
    ("Toilet installation is part of the bathroom renovation process.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 49, "SPECIALIZATION")]}),
    ("They regularly handle toilet installations for clients.", 
     {"entities": [(25, 44, "SKILLS"), (48, 64, "SERVICE"), (68, 75, "SPECIALIZATION")]}),
    ("The team focuses on installing toilets efficiently.", 
     {"entities": [(24, 41, "SKILLS"), (0, 16, "SERVICE"), (45, 52, "SPECIALIZATION")]}),
    ("Installation of toilet was completed yesterday.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Installation of toilets requires careful alignment.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("Installing of toilet is scheduled for tomorrow.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Installing of toilets is a common task for the crew.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("They are installing toilet in the guest bathroom.", 
     {"entities": [(9, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 56, "SPECIALIZATION")]}),
    ("Technicians are installing toilets across multiple homes.", 
     {"entities": [(17, 36, "SKILLS"), (37, 53, "SERVICE"), (57, 64, "SPECIALIZATION")]}),
    ("The plumber installed a toilet yesterday.", 
     {"entities": [(15, 28, "SKILLS"), (0, 16, "SERVICE"), (32, 39, "SPECIALIZATION")]}),
    ("They installed a toilets in the new office last week.", 
     {"entities": [(6, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("Installed toilet in the guest restroom by the team.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 47, "SPECIALIZATION")]}),
    ("The workers installed toilets in every unit.", 
     {"entities": [(12, 28, "SKILLS"), (32, 48, "SERVICE"), (52, 59, "SPECIALIZATION")]}),
    # Toilet Repair
    ("The plumber performs toilet repair in all bathrooms.", 
     {"entities": [(4, 11, "SPECIALIZATION"), (20, 36, "SERVICE"), (37, 51, "SKILLS")]}),
    ("Toilet repairs are essential to maintain hygiene.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 44, "SPECIALIZATION")]}),
    ("Technicians handle toilet repairs every week.", 
     {"entities": [(24, 39, "SKILLS"), (0, 16, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Repairing toilet is part of regular maintenance tasks.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 44, "SPECIALIZATION")]}),
    ("Repairing toilets requires skill and precision.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 46, "SPECIALIZATION")]}),
    ("They are repairing of toilet in the master bathroom.", 
     {"entities": [(9, 27, "SKILLS"), (31, 47, "SERVICE"), (51, 58, "SPECIALIZATION")]}),
    ("Repairing of toilets takes time when plumbing is old.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 49, "SPECIALIZATION")]}),
    ("The plumber repaired toilet last Tuesday.", 
     {"entities": [(15, 29, "SKILLS"), (0, 16, "SERVICE"), (33, 40, "SPECIALIZATION")]}),
    ("He repaired toilets in the guest restroom yesterday.", 
     {"entities": [(3, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 49, "SPECIALIZATION")]}),
    ("The technician repaired a toilet after the leak was fixed.", 
     {"entities": [(19, 33, "SKILLS"), (0, 16, "SERVICE"), (37, 44, "SPECIALIZATION")]}),
    ("Repaired a toilets quickly by the maintenance crew.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 46, "SPECIALIZATION")]}),
    # Leak Fixing
    ("Leak fixing is crucial to prevent water damage in bathrooms.", 
     {"entities": [(0, 12, "SKILLS"), (16, 28, "SERVICE"), (32, 39, "SPECIALIZATION")]}),
    ("Fixing leak requires proper tools and expertise.", 
     {"entities": [(0, 12, "SKILLS"), (13, 25, "SERVICE"), (29, 36, "SPECIALIZATION")]}),
    ("They are fixing leaks in the old building plumbing.", 
     {"entities": [(9, 21, "SKILLS"), (25, 37, "SERVICE"), (41, 48, "SPECIALIZATION")]}),
    ("Fixing of leak is part of the maintenance checklist.", 
     {"entities": [(0, 15, "SKILLS"), (19, 31, "SERVICE"), (35, 42, "SPECIALIZATION")]}),
    ("Fixing of leaks takes priority after heavy rain.", 
     {"entities": [(0, 16, "SKILLS"), (20, 32, "SERVICE"), (36, 43, "SPECIALIZATION")]}),
    ("The plumber fixed a leak under the kitchen sink.", 
     {"entities": [(16, 28, "SKILLS"), (0, 16, "SERVICE"), (32, 39, "SPECIALIZATION")]}),
    ("He fixed a leaks in the restroom yesterday.", 
     {"entities": [(3, 14, "SKILLS"), (18, 30, "SERVICE"), (34, 41, "SPECIALIZATION")]}),
    ("Fixed leak was repaired by the maintenance team quickly.", 
     {"entities": [(0, 10, "SKILLS"), (14, 26, "SERVICE"), (30, 37, "SPECIALIZATION")]}),
    ("The workers fixed leaks in multiple apartments.", 
     {"entities": [(12, 23, "SKILLS"), (27, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    # Toilet Unclogging
    ("Toilet unclogging is an important maintenance task.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 49, "SPECIALIZATION")]}),
    ("Toilet uncloggings occur frequently in busy restrooms.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Unclogging toilet requires special tools and care.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 44, "SPECIALIZATION")]}),
    ("Unclogging toilets is often performed by professional plumbers.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 46, "SPECIALIZATION")]}),
    ("Unclogging of toilet was scheduled for the morning.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Unclogging of toilets takes precedence in commercial buildings.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("The plumber unclogged toilet in the master bathroom yesterday.", 
     {"entities": [(12, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 54, "SPECIALIZATION")]}),
    ("He unclogged toilets quickly to prevent water overflow.", 
     {"entities": [(3, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 45, "SPECIALIZATION")]}),
    ("They unclogged a toilet in the office restroom.", 
     {"entities": [(5, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("The maintenance team unclogged a toilets yesterday.", 
     {"entities": [(17, 32, "SKILLS"), (36, 52, "SERVICE"), (56, 63, "SPECIALIZATION")]}),
    # Flushing Repair System
    ("Flushing system repair is critical to proper toilet function.", 
     {"entities": [(0, 22, "SKILLS"), (26, 42, "SERVICE"), (46, 53, "SPECIALIZATION")]}),
    ("Flushing systems repair occurs regularly in public restrooms.", 
     {"entities": [(0, 24, "SKILLS"), (28, 44, "SERVICE"), (48, 55, "SPECIALIZATION")]}),
    ("Repairing flushing system requires precision and care.", 
     {"entities": [(0, 23, "SKILLS"), (24, 41, "SERVICE"), (45, 52, "SPECIALIZATION")]}),
    ("Repairing flushing systems is often handled by professional plumbers.", 
     {"entities": [(0, 25, "SKILLS"), (26, 43, "SERVICE"), (47, 54, "SPECIALIZATION")]}),
    ("Repairing of flushing system was scheduled for the morning.", 
     {"entities": [(0, 26, "SKILLS"), (30, 47, "SERVICE"), (51, 58, "SPECIALIZATION")]}),
    ("Repairing of flushing systems takes priority in commercial buildings.", 
     {"entities": [(0, 27, "SKILLS"), (31, 48, "SERVICE"), (52, 59, "SPECIALIZATION")]}),
    ("The plumber repaired flushing system yesterday.", 
     {"entities": [(15, 36, "SKILLS"), (0, 16, "SERVICE"), (40, 47, "SPECIALIZATION")]}),
    ("He repaired flushing systems in multiple apartments.", 
     {"entities": [(3, 25, "SKILLS"), (26, 43, "SERVICE"), (47, 54, "SPECIALIZATION")]}),
    ("They repaired a flushing system quickly in the restroom.", 
     {"entities": [(5, 26, "SKILLS"), (30, 47, "SERVICE"), (51, 58, "SPECIALIZATION")]}),
    ("The maintenance team repaired a flushing systems yesterday.", 
     {"entities": [(17, 38, "SKILLS"), (42, 59, "SERVICE"), (63, 70, "SPECIALIZATION")]}),
    #Toilet Replacement
    ("Toilet replacement is necessary when toilets are old.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 49, "SPECIALIZATION")]}),
    ("Toilet replacements occur frequently in hotels.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Replacing toilet is part of the regular maintenance routine.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 44, "SPECIALIZATION")]}),
    ("Replacing toilets requires careful handling by the team.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 45, "SPECIALIZATION")]}),
    ("Replacing of toilet was scheduled for this morning.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 50, "SPECIALIZATION")]}),
    ("Replacing of toilets takes priority in commercial buildings.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("The plumber replaced toilet in the guest bathroom yesterday.", 
     {"entities": [(15, 30, "SKILLS"), (31, 47, "SERVICE"), (51, 58, "SPECIALIZATION")]}),
    ("He replaced toilets across multiple units quickly.", 
     {"entities": [(3, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 45, "SPECIALIZATION")]}),
    ("They replaced a toilet in the office restroom.", 
     {"entities": [(5, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 51, "SPECIALIZATION")]}),
    ("The maintenance team replaced a toilets yesterday.", 
     {"entities": [(17, 32, "SKILLS"), (36, 52, "SERVICE"), (56, 63, "SPECIALIZATION")]}),

    # ----------- Faucet and Sink Maintenance -----------
    #Faucet Installation
    ("Faucet installation is essential for new kitchen setups.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 56, "SPECIALIZATION")]}),
    ("Faucet installation occurs frequently in commercial kitchens.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 56, "SPECIALIZATION")]}),
    ("Installing faucet requires precision and proper tools.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 47, "SPECIALIZATION")]}),
    ("Installing faucets is often handled by professional plumbers.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 48, "SPECIALIZATION")]}),
    ("Installing of faucet was scheduled for the morning.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 57, "SPECIALIZATION")]}),
    ("Installing of faucets takes priority in commercial projects.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 58, "SPECIALIZATION")]}),
    ("Installation of faucet is part of kitchen remodeling.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 57, "SPECIALIZATION")]}),
    ("Installation of faucets requires careful handling by the team.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 58, "SPECIALIZATION")]}),
    ("The plumber installed a faucet in the new kitchen.", 
     {"entities": [(15, 29, "SKILLS"), (30, 50, "SERVICE"), (54, 64, "SPECIALIZATION")]}),
    ("He installed a faucets quickly in the guest bathroom.", 
     {"entities": [(3, 18, "SKILLS"), (19, 39, "SERVICE"), (43, 53, "SPECIALIZATION")]}),
    ("Installed faucet in the office restroom by the maintenance team.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 53, "SPECIALIZATION")]}),
    ("The workers installed faucets in multiple units yesterday.", 
     {"entities": [(12, 27, "SKILLS"), (28, 48, "SERVICE"), (52, 62, "SPECIALIZATION")]}),
    #Faucet Repair
     ("Faucet repair is essential to prevent leaks in kitchens.", 
     {"entities": [(0, 12, "SKILLS"), (16, 28, "SERVICE"), (32, 42, "SPECIALIZATION")]}),
    ("Faucet repairs are regularly performed in commercial properties.", 
     {"entities": [(0, 13, "SKILLS"), (17, 29, "SERVICE"), (33, 43, "SPECIALIZATION")]}),
    ("Repairing faucet requires careful handling and proper tools.", 
     {"entities": [(0, 16, "SKILLS"), (17, 29, "SERVICE"), (33, 43, "SPECIALIZATION")]}),
    ("Repairing faucets is often handled by professional plumbers.", 
     {"entities": [(0, 17, "SKILLS"), (18, 30, "SERVICE"), (34, 44, "SPECIALIZATION")]}),
    ("Repairing of faucet was scheduled for this morning.", 
     {"entities": [(0, 20, "SKILLS"), (24, 36, "SERVICE"), (40, 50, "SPECIALIZATION")]}),
    ("Repairing of faucets takes priority in commercial projects.", 
     {"entities": [(0, 21, "SKILLS"), (25, 37, "SERVICE"), (41, 51, "SPECIALIZATION")]}),
    ("The plumber repaired a faucet in the new kitchen.", 
     {"entities": [(15, 29, "SKILLS"), (30, 42, "SERVICE"), (46, 56, "SPECIALIZATION")]}),
    ("He repaired a faucets quickly to prevent water spillage.", 
     {"entities": [(3, 18, "SKILLS"), (19, 31, "SERVICE"), (35, 45, "SPECIALIZATION")]}),
    ("Repaired faucet in the office restroom by the maintenance team.", 
     {"entities": [(0, 15, "SKILLS"), (19, 31, "SERVICE"), (35, 45, "SPECIALIZATION")]}),
    ("The team repaired faucets in multiple apartments yesterday.", 
     {"entities": [(12, 27, "SKILLS"), (28, 40, "SERVICE"), (44, 54, "SPECIALIZATION")]}),
    #Faucet Replacement
    ("Faucet replacement is necessary when old faucets leak.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 51, "SPECIALIZATION")]}),
    ("Faucet replacements occur frequently in commercial kitchens.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 52, "SPECIALIZATION")]}),
    ("Replacing faucet requires proper tools and precision.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 47, "SPECIALIZATION")]}),
    ("Replacing faucets is often performed by professional plumbers.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 48, "SPECIALIZATION")]}),
    ("Replacing of faucet was scheduled for the morning.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 53, "SPECIALIZATION")]}),
    ("Replacing of faucets takes priority in commercial projects.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 54, "SPECIALIZATION")]}),
    ("The plumber replaced faucet in the guest kitchen.", 
     {"entities": [(15, 30, "SKILLS"), (31, 47, "SERVICE"), (51, 61, "SPECIALIZATION")]}),
    ("He replaced faucets quickly to prevent water spillage.", 
     {"entities": [(3, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 49, "SPECIALIZATION")]}),
    ("They replaced a faucet in the office restroom.", 
     {"entities": [(5, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 54, "SPECIALIZATION")]}),
    ("The maintenance team replaced a faucets yesterday.", 
     {"entities": [(17, 32, "SKILLS"), (36, 52, "SERVICE"), (56, 66, "SPECIALIZATION")]}),
    #Sink Installation
    ("Sink installation is crucial for new kitchen setups.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 59, "SPECIALIZATION")]}),
    ("Sink installations are scheduled frequently in commercial buildings.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Installing sink requires proper tools and careful handling.", 
     {"entities": [(0, 15, "SKILLS"), (16, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Installing sinks is often performed by professional plumbers.", 
     {"entities": [(0, 16, "SKILLS"), (17, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Installing of sink was scheduled for the morning.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Installing of sinks takes priority in renovation projects.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("Installation of sink is part of bathroom remodeling.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Installation of sinks requires careful alignment and tools.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("The plumber installed a sink in the new kitchen.", 
     {"entities": [(15, 28, "SKILLS"), (29, 49, "SERVICE"), (53, 67, "SPECIALIZATION")]}),
    ("He installed a sinks quickly in the office restroom.", 
     {"entities": [(3, 16, "SKILLS"), (17, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Installed sink in the guest bathroom by the maintenance team.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("The workers installed sinks in multiple apartments yesterday.", 
     {"entities": [(12, 25, "SKILLS"), (26, 46, "SERVICE"), (50, 64, "SPECIALIZATION")]}),
    #Sink Replacement
    ("Sink replacement is necessary when old sinks leak.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Sink replacements occur frequently in commercial kitchens.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Replacing sink requires proper tools and precision.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Replacing sinks is often performed by professional plumbers.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Replacement of sink was scheduled for the morning.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("Replacement of sinks takes priority in renovation projects.", 
     {"entities": [(0, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 59, "SPECIALIZATION")]}),
    ("Replacing of sink requires careful handling by the team.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Replacing of sinks is part of the maintenance checklist.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("The plumber replaced a sink in the new kitchen.", 
     {"entities": [(15, 29, "SKILLS"), (30, 46, "SERVICE"), (50, 64, "SPECIALIZATION")]}),
    ("He replaced a sinks quickly in the office restroom.", 
     {"entities": [(3, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Replaced sink in the guest bathroom by the maintenance team.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The workers replaced sinks in multiple apartments yesterday.", 
     {"entities": [(12, 25, "SKILLS"), (26, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    #Sink Unclogging
    ("Sink unclogging is necessary to maintain proper drainage.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 43, "SPECIALIZATION")]}),
    ("Unclogging sink occurs frequently in commercial kitchens.", 
     {"entities": [(0, 15, "SKILLS"), (16, 30, "SERVICE"), (34, 38, "SPECIALIZATION")]}),
    ("Unclogging sinks requires proper tools and careful handling.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 41, "SPECIALIZATION")]}),
    ("Unclogging of sink is often performed by maintenance professionals.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 47, "SPECIALIZATION")]}),
    ("Unclogging of sinks takes priority after heavy usage.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 48, "SPECIALIZATION")]}),
    ("The plumber unclogged a sink in the restroom yesterday.", 
     {"entities": [(15, 30, "SKILLS"), (31, 47, "SERVICE"), (51, 55, "SPECIALIZATION")]}),
    ("He unclogged a sinks quickly to restore drainage.", 
     {"entities": [(3, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 43, "SPECIALIZATION")]}),
    ("Unclogged sink was repaired by the maintenance team.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 41, "SPECIALIZATION")]}),
    ("The team unclogged sinks in multiple apartments yesterday.", 
     {"entities": [(9, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 49, "SPECIALIZATION")]}),

      # ----------- Drain Unclogging -----------  
    #Drain Cleaning
    ("Drain cleaning is essential to prevent clogs and backups.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 48, "SPECIALIZATION")]}),
    ("Drain cleanings occur regularly in commercial properties.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 50, "SPECIALIZATION")]}),
    ("Cleaning drain requires proper tools and careful handling.", 
     {"entities": [(0, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 46, "SPECIALIZATION")]}),
    ("Cleaning drains is often performed by professional plumbers.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 47, "SPECIALIZATION")]}),
    ("Cleaning of drain takes priority after heavy rainfall.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 52, "SPECIALIZATION")]}),
    ("Cleaning of drains is part of routine maintenance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 53, "SPECIALIZATION")]}),
    ("The plumber cleaned a drain in the basement yesterday.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 60, "SPECIALIZATION")]}),
    ("He cleaned a drains quickly to restore proper flow.", 
     {"entities": [(3, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 49, "SPECIALIZATION")]}),
    ("Cleaned drain was maintained by the maintenance team.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 47, "SPECIALIZATION")]}),
    ("The team cleaned drains in multiple apartments yesterday.", 
     {"entities": [(9, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 56, "SPECIALIZATION")]}),
    #Drain Snaking
     ("Snaking drain requires proper tools and expertise.", 
     {"entities": [(0, 12, "SKILLS"), (13, 29, "SERVICE"), (33, 45, "SPECIALIZATION")]}),
    ("Snaking drains is often handled by professional plumbers.", 
     {"entities": [(0, 13, "SKILLS"), (14, 30, "SERVICE"), (34, 46, "SPECIALIZATION")]}),
    ("Snaking of drain was scheduled for the morning.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 52, "SPECIALIZATION")]}),
    ("Snaking of drains is part of routine maintenance.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 53, "SPECIALIZATION")]}),
    ("The plumber snaked a drain to clear the blockage.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 61, "SPECIALIZATION")]}),
    ("He snaked a drains quickly to restore proper flow.", 
     {"entities": [(3, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 50, "SPECIALIZATION")]}),
    ("Snaked drain was maintained by the maintenance team.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("The team snaked drains in multiple apartments yesterday.", 
     {"entities": [(9, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 57, "SPECIALIZATION")]}),
    ("Drain repair is sometimes necessary after heavy usage.", 
     {"entities": [(0, 11, "SKILLS"), (15, 31, "SERVICE"), (35, 47, "SPECIALIZATION")]}),
    ("Routine drain repair prevents blockages in commercial buildings.", 
     {"entities": [(8, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 55, "SPECIALIZATION")]}),
    #Hydro Jetting
    ("Hydro jetting is used to clear tough drain blockages.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 49, "SPECIALIZATION")]}),
    ("Hydro jetting prevents buildup in commercial plumbing systems.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 49, "SPECIALIZATION")]}),
    ("Performing hydro jetting requires high-pressure equipment.", 
     {"entities": [(10, 23, "SKILLS"), (24, 40, "SERVICE"), (44, 56, "SPECIALIZATION")]}),
    ("Executing hydro jetting is part of professional drain maintenance.", 
     {"entities": [(10, 23, "SKILLS"), (24, 40, "SERVICE"), (44, 56, "SPECIALIZATION")]}),
    ("The plumber completed hydro jetting on the main sewer line.", 
     {"entities": [(19, 32, "SKILLS"), (33, 49, "SERVICE"), (53, 65, "SPECIALIZATION")]}),
    ("He performed hydro jetting yesterday to unclog the drains.", 
     {"entities": [(13, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 59, "SPECIALIZATION")]}),
    #Clog Removal
    ("Clog removal is necessary to maintain proper drainage.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("Removal of clog is performed frequently in commercial kitchens.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 51, "SPECIALIZATION")]}),
    ("Removal of clogs helps prevent plumbing emergencies.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 52, "SPECIALIZATION")]}),
    ("Removing clog requires proper tools and careful handling.", 
     {"entities": [(0, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 47, "SPECIALIZATION")]}),
    ("Removing clogs is often handled by professional plumbers.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("Removing of clog was part of the routine maintenance.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 53, "SPECIALIZATION")]}),
    ("Removing of clogs requires high-pressure equipment.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 54, "SPECIALIZATION")]}),
    ("The plumber removed a clog from the kitchen sink.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 61, "SPECIALIZATION")]}),
    ("He removed a clogs quickly to restore drainage.", 
     {"entities": [(3, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 51, "SPECIALIZATION")]}),
    ("Removed clog was maintained by the maintenance team.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("The team removed clogs in multiple apartments yesterday.", 
     {"entities": [(9, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 57, "SPECIALIZATION")]}),

      # ----------- Shower Maintenance -----------
    #showerhead installation
    ("Clog removal is necessary to maintain proper drainage.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("Removal of clog is performed frequently in commercial kitchens.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 51, "SPECIALIZATION")]}),
    ("Removal of clogs helps prevent plumbing emergencies.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 52, "SPECIALIZATION")]}),
    ("Removing clog requires proper tools and careful handling.", 
     {"entities": [(0, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 47, "SPECIALIZATION")]}),
    ("Removing clogs is often handled by professional plumbers.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("Removing of clog was part of the routine maintenance.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 53, "SPECIALIZATION")]}),
    ("Removing of clogs requires high-pressure equipment.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 54, "SPECIALIZATION")]}),
    ("The plumber removed a clog from the kitchen sink.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 61, "SPECIALIZATION")]}),
    ("He removed a clogs quickly to restore drainage.", 
     {"entities": [(3, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 51, "SPECIALIZATION")]}),
    ("Removed clog was maintained by the maintenance team.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 48, "SPECIALIZATION")]}),
    ("The team removed clogs in multiple apartments yesterday.", 
     {"entities": [(9, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 57, "SPECIALIZATION")]}),
    #showerhead repair
    ("Showerhead repair is necessary to fix leaks in bathrooms.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Showerhead repairs are frequently performed by plumbers.", 
     {"entities": [(0, 18, "SKILLS"), (22, 38, "SERVICE"), (42, 56, "SPECIALIZATION")]}),
    ("Repairing showerhead requires proper tools and skill.", 
     {"entities": [(0, 20, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Repairing showerheads is part of routine bathroom maintenance.", 
     {"entities": [(0, 21, "SKILLS"), (22, 38, "SERVICE"), (42, 56, "SPECIALIZATION")]}),
    ("Repairing of showerhead was scheduled for this morning.", 
     {"entities": [(0, 23, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("Repairing of showerheads helps prevent water leaks.", 
     {"entities": [(0, 24, "SKILLS"), (28, 44, "SERVICE"), (48, 62, "SPECIALIZATION")]}),
    ("The plumber repaired a showerhead in the master bathroom.", 
     {"entities": [(15, 31, "SKILLS"), (32, 48, "SERVICE"), (52, 66, "SPECIALIZATION")]}),
    ("He repaired showerheads quickly to restore water flow.", 
     {"entities": [(3, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    #valve replacement
    ("Valve replacement is needed to ensure proper water control.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Valve replacements are commonly performed during plumbing upgrades.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Replacing valve requires proper tools and attention to detail.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Replacing valves is part of routine bathroom maintenance.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Replacing of valve was scheduled for the morning.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Replacing of valves ensures smooth water operation.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("Replacement of valve is sometimes necessary after leaks.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Replacement of valves helps maintain plumbing systems.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("The plumber replaced a valve in the shower system.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 63, "SPECIALIZATION")]}),
    ("He replaced valves quickly to restore proper flow.", 
     {"entities": [(3, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    #shower pipe repair
    ("Shower pipe repair is necessary to prevent water leaks.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Shower pipe repairs are regularly performed in bathrooms.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("Repairing shower pipe requires high-quality tools.", 
     {"entities": [(0, 22, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Repairing shower pipes is part of standard maintenance.", 
     {"entities": [(0, 23, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("Repairing of shower pipe was scheduled this morning.", 
     {"entities": [(0, 25, "SKILLS"), (29, 45, "SERVICE"), (49, 63, "SPECIALIZATION")]}),
    ("Repairing of shower pipes prevents water damage.", 
     {"entities": [(0, 26, "SKILLS"), (30, 46, "SERVICE"), (50, 64, "SPECIALIZATION")]}),
    ("The plumber repaired a shower pipe in the master bathroom.", 
     {"entities": [(15, 31, "SKILLS"), (32, 48, "SERVICE"), (52, 66, "SPECIALIZATION")]}),
    ("He repaired shower pipes quickly to restore water flow.", 
     {"entities": [(3, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),

      # ----------- Bathtub Maintenance -----------    
    #bathtub installation
    ("Bathtub installation is necessary for new bathroom setups.", 
     {"entities": [(0, 19, "SKILLS"), (23, 41, "SERVICE"), (45, 59, "SPECIALIZATION")]}),
    ("Bathtub installations are performed by professional plumbers.", 
     {"entities": [(0, 20, "SKILLS"), (24, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Installing bathtub requires proper tools and careful handling.", 
     {"entities": [(0, 18, "SKILLS"), (19, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Installing bathtubs is part of standard bathroom maintenance.", 
     {"entities": [(0, 19, "SKILLS"), (20, 38, "SERVICE"), (42, 56, "SPECIALIZATION")]}),
    ("Installation of bathtub was scheduled for the morning.", 
     {"entities": [(0, 21, "SKILLS"), (25, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("Installation of bathtubs requires precise measurements.", 
     {"entities": [(0, 22, "SKILLS"), (26, 44, "SERVICE"), (48, 62, "SPECIALIZATION")]}),
    ("Installing of bathtub is handled by experienced technicians.", 
     {"entities": [(0, 23, "SKILLS"), (27, 45, "SERVICE"), (49, 63, "SPECIALIZATION")]}),
    ("Installing of bathtubs ensures proper water alignment.", 
     {"entities": [(0, 24, "SKILLS"), (28, 46, "SERVICE"), (50, 64, "SPECIALIZATION")]}),
    #bathub repair
    ("Bathtub repair is necessary to fix leaks and cracks.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Bathtub repairs are performed regularly to maintain quality.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Repairing bathtub requires proper tools and expertise.", 
     {"entities": [(0, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Repairing bathtubs is part of routine bathroom maintenance.", 
     {"entities": [(0, 20, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Repairing of bathtub was scheduled for this afternoon.", 
     {"entities": [(0, 22, "SKILLS"), (26, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Repairing of bathtubs helps prevent water damage.", 
     {"entities": [(0, 23, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("The plumber repaired a bathtub in the master bathroom.", 
     {"entities": [(15, 30, "SKILLS"), (31, 47, "SERVICE"), (51, 65, "SPECIALIZATION")]}),
    ("He repaired bathtubs quickly to restore water flow.", 
     {"entities": [(3, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    #fixture and repair
    ("Fixture replacement is necessary when old fixtures leak.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Fixture replacements are scheduled regularly by plumbers.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("Replacing fixture requires proper tools and attention.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Replacing fixtures is part of standard maintenance.", 
     {"entities": [(0, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Replacing of fixture was scheduled for the morning.", 
     {"entities": [(0, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 59, "SPECIALIZATION")]}),
    ("Replacing of fixtures ensures proper water operation.", 
     {"entities": [(0, 22, "SKILLS"), (26, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Replacement of fixture is sometimes necessary after leaks.", 
     {"entities": [(0, 22, "SKILLS"), (26, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("Replacement of fixtures helps maintain bathroom systems.", 
     {"entities": [(0, 23, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("The plumber replaced a fixture in the bathroom.", 
     {"entities": [(15, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("He replaced fixtures quickly to restore functionality.", 
     {"entities": [(3, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    #caulking and sealing
    ("Caulking and sealing prevents water leaks in bathtubs.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Sealing and caulking is necessary for proper waterproofing.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Caulking of gap requires careful attention.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Caulking of gaps is part of standard bathroom maintenance.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("He caulked a gap around the bathtub.", 
     {"entities": [(3, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("Sealed gaps prevent water from leaking behind tiles.", 
     {"entities": [(0, 11, "SKILLS"), (12, 28, "SERVICE"), (32, 46, "SPECIALIZATION")]}),
    #Drain Repairs
    ("Drain repairs are necessary to maintain proper water flow.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Repairing drain requires proper tools and careful handling.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Repairing drains is often performed by professional plumbers.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("The plumber repaired a drain in the bathroom.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 63, "SPECIALIZATION")]}),
    ("He repaired drains quickly to restore proper flow.", 
     {"entities": [(3, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),

      # ----------- Pipe Repair -----------     
    #leak detection
    ("Leak detection is crucial to prevent water damage in pipes.", 
     {"entities": [(0, 14, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Leak detections are regularly performed in commercial plumbing systems.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Detection of leak requires proper tools and expertise.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Detection of leaks is part of routine plumbing maintenance.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Detecting of leak helps prevent major pipe failures.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Detecting of leaks ensures plumbing systems are safe.", 
     {"entities": [(0, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Detecting leak is part of routine water line inspections.", 
     {"entities": [(0, 14, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Detecting leaks prevents future plumbing issues.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("The plumber detected a leak in the kitchen sink.", 
     {"entities": [(15, 28, "SKILLS"), (29, 45, "SERVICE"), (49, 63, "SPECIALIZATION")]}),
    ("He detected a leaks quickly to prevent water damage.", 
     {"entities": [(3, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Detected leak was repaired by the maintenance team.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The team detected leaks in multiple water lines yesterday.", 
     {"entities": [(9, 22, "SKILLS"), (26, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    #pipe cutting
    ("Pipe cutting is necessary to install new plumbing lines.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Cutting pipe requires proper tools and accurate measurements.", 
     {"entities": [(0, 12, "SKILLS"), (13, 29, "SERVICE"), (33, 47, "SPECIALIZATION")]}),
    ("Cutting pipes is often performed by professional plumbers.", 
     {"entities": [(0, 13, "SKILLS"), (14, 30, "SERVICE"), (34, 48, "SPECIALIZATION")]}),
    ("Cutting of pipe helps prepare plumbing installations.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Cutting of pipes is necessary for replacing old plumbing.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("The plumber cut a pipe to connect the new sink.", 
     {"entities": [(15, 25, "SKILLS"), (26, 42, "SERVICE"), (46, 60, "SPECIALIZATION")]}),
    ("He cut a pipes quickly to restore water flow.", 
     {"entities": [(3, 12, "SKILLS"), (13, 29, "SERVICE"), (33, 47, "SPECIALIZATION")]}),
    ("Cut pipe was replaced to fix the leaking section.", 
     {"entities": [(0, 8, "SKILLS"), (12, 28, "SERVICE"), (32, 46, "SPECIALIZATION")]}),
    ("The team cut pipes in multiple locations yesterday.", 
     {"entities": [(9, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    #pipe fitting
    ("Pipe fitting is necessary to connect new plumbing lines.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Pipe fittings are regularly performed by professional plumbers.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Fitting pipe requires accurate measurements and proper tools.", 
     {"entities": [(0, 12, "SKILLS"), (13, 29, "SERVICE"), (33, 47, "SPECIALIZATION")]}),
    ("Fitting pipes is a crucial step in plumbing installation.", 
     {"entities": [(0, 13, "SKILLS"), (14, 30, "SERVICE"), (34, 48, "SPECIALIZATION")]}),
    ("Fitting of pipe ensures proper water flow.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Fitting of pipes is performed during pipe replacement.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The plumber fitted a pipe in the bathroom.", 
     {"entities": [(15, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("He fitted a pipes quickly to restore water flow.", 
     {"entities": [(3, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("Fitted pipe was inspected after the installation.", 
     {"entities": [(0, 11, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("The team fitted pipes in multiple locations yesterday.", 
     {"entities": [(9, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    #replacing pipe
    ("Pipe replacement is necessary to fix damaged plumbing.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Pipe replacements are performed regularly in commercial buildings.", 
     {"entities": [(0, 17, "SKILLS"), (21, 37, "SERVICE"), (41, 55, "SPECIALIZATION")]}),
    ("Replacing pipe requires proper tools and expertise.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Replacing pipes is part of routine maintenance.", 
     {"entities": [(0, 17, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Replacing of pipe was scheduled for the morning.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Replacing of pipes ensures proper water flow.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("Replacement of pipe is sometimes necessary after leaks.", 
     {"entities": [(0, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    ("Replacement of pipes helps maintain plumbing systems.", 
     {"entities": [(0, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),
    ("The plumber replaced a pipe in the kitchen.", 
     {"entities": [(15, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("He replaced pipes quickly to restore proper flow.", 
     {"entities": [(3, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    #pipe welding
    ("Pipe welding is necessary to connect metal plumbing lines.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Pipe weldings are performed by certified plumbers.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Welding pipe requires proper equipment and safety measures.", 
     {"entities": [(0, 12, "SKILLS"), (13, 29, "SERVICE"), (33, 47, "SPECIALIZATION")]}),
    ("Welding pipes is part of standard plumbing maintenance.", 
     {"entities": [(0, 13, "SKILLS"), (14, 30, "SERVICE"), (34, 48, "SPECIALIZATION")]}),
    ("Welding of pipe ensures strong and leak-proof connections.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Welding of pipes is required for replacing old metal lines.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The plumber welded a pipe in the basement.", 
     {"entities": [(15, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("He welded a pipes quickly to restore water flow.", 
     {"entities": [(3, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("Welded pipe was inspected for quality assurance.", 
     {"entities": [(0, 11, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("The team welded pipes in multiple locations yesterday.", 
     {"entities": [(9, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),
    #joint sealing
    ("Joint sealing is necessary to prevent leaks in pipe connections.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Joint sealings are performed regularly in plumbing maintenance.", 
     {"entities": [(0, 14, "SKILLS"), (18, 34, "SERVICE"), (38, 52, "SPECIALIZATION")]}),
    ("Sealing joint requires proper tools and sealant application.", 
     {"entities": [(0, 13, "SKILLS"), (14, 30, "SERVICE"), (34, 48, "SPECIALIZATION")]}),
    ("Sealing joints is part of standard pipe maintenance.", 
     {"entities": [(0, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("Sealing of joint ensures water-tight pipe connections.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Sealing of joints is required during plumbing repairs.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The plumber sealed a joint in the kitchen sink.", 
     {"entities": [(15, 27, "SKILLS"), (28, 44, "SERVICE"), (48, 62, "SPECIALIZATION")]}),
    ("He sealed a joints quickly to prevent leaks.", 
     {"entities": [(3, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Sealed joint was inspected for quality assurance.", 
     {"entities": [(0, 11, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("The team sealed joints in multiple areas yesterday.", 
     {"entities": [(9, 20, "SKILLS"), (24, 40, "SERVICE"), (44, 58, "SPECIALIZATION")]}),

      # ----------- Water Line Maintenance -----------    
    #water linee installation
    ("Water line installation is required for new plumbing systems.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 67, "SPECIALIZATION")]}),
    ("Water line installations are performed by certified plumbers.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 68, "SPECIALIZATION")]}),
    ("Installation of water line was scheduled for this morning.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 71, "SPECIALIZATION")]}),
    ("Installation of water lines requires precise measurements.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 72, "SPECIALIZATION")]}),
    ("Installing of water line ensures proper water distribution.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 71, "SPECIALIZATION")]}),
    ("Installing of water lines is part of standard plumbing work.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 72, "SPECIALIZATION")]}),
    ("Installed a water line in the basement yesterday.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 67, "SPECIALIZATION")]}),
    ("Installed a water lines to replace old damaged pipes.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 68, "SPECIALIZATION")]}),
    ("Installed water line was inspected for proper flow.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 64, "SPECIALIZATION")]}),
    ("Installed water lines connect multiple fixtures in the house.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 65, "SPECIALIZATION")]}),
    #pipe fitting
    ("Pipe fitting is essential for connecting new water lines.", 
     {"entities": [(0, 12, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Pipe fittings are performed by certified plumbers during installations.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Fitting pipe requires precise alignment for proper water flow.", 
     {"entities": [(0, 12, "SKILLS"), (13, 29, "SERVICE"), (33, 47, "SPECIALIZATION")]}),
    ("Fitting pipes is part of water line maintenance.", 
     {"entities": [(0, 13, "SKILLS"), (14, 30, "SERVICE"), (34, 48, "SPECIALIZATION")]}),
    ("Fitting of pipe ensures leak-proof connections.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Fitting of pipes is required during water line replacements.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The plumber fitted a pipe in the basement.", 
     {"entities": [(15, 26, "SKILLS"), (27, 43, "SERVICE"), (47, 61, "SPECIALIZATION")]}),
    ("He fitted a pipes quickly to restore water flow.", 
     {"entities": [(3, 14, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("Fitted pipe was checked for proper installation.", 
     {"entities": [(0, 11, "SKILLS"), (15, 31, "SERVICE"), (35, 49, "SPECIALIZATION")]}),
    ("The team fitted pipes in multiple areas yesterday.", 
     {"entities": [(9, 19, "SKILLS"), (23, 39, "SERVICE"), (43, 57, "SPECIALIZATION")]}),

    #pipe connection
     # Present simple
    ("Pipe connection is necessary to join new plumbing lines.", 
     {"entities": [(0, 15, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Pipe connections are performed regularly to maintain water flow.", 
     {"entities": [(0, 16, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Connecting pipe requires proper alignment and sealants.", 
     {"entities": [(0, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Connecting pipes ensures leak-proof water lines.", 
     {"entities": [(0, 16, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("Connecting of pipe is part of water line installation.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Connecting of pipes helps maintain proper water flow.", 
     {"entities": [(0, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("Connection of pipe was inspected for leaks.", 
     {"entities": [(0, 18, "SKILLS"), (19, 35, "SERVICE"), (39, 53, "SPECIALIZATION")]}),
    ("Connection of pipes ensures proper water distribution.", 
     {"entities": [(0, 19, "SKILLS"), (20, 36, "SERVICE"), (40, 54, "SPECIALIZATION")]}),
    ("The plumber connected a pipe in the basement.", 
     {"entities": [(15, 27, "SKILLS"), (28, 44, "SERVICE"), (48, 62, "SPECIALIZATION")]}),
    ("He connected a pipes quickly to restore water flow.", 
     {"entities": [(3, 15, "SKILLS"), (16, 32, "SERVICE"), (36, 50, "SPECIALIZATION")]}),
    ("Connected pipe was tested for proper sealing.", 
     {"entities": [(0, 13, "SKILLS"), (17, 33, "SERVICE"), (37, 51, "SPECIALIZATION")]}),
    ("The team connected pipes in multiple locations yesterday.", 
     {"entities": [(9, 21, "SKILLS"), (25, 41, "SERVICE"), (45, 59, "SPECIALIZATION")]}),
    #water line repair
    ("Water line repair is necessary to fix leaking pipes.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Water line repairs are performed regularly to maintain water flow.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 62, "SPECIALIZATION")]}),
    ("Repairing water line requires proper tools and sealants.", 
     {"entities": [(0, 19, "SKILLS"), (20, 40, "SERVICE"), (44, 60, "SPECIALIZATION")]}),
    ("Repairing water lines ensures leak-proof connections.", 
     {"entities": [(0, 20, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Repairing of water line was scheduled for this morning.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 66, "SPECIALIZATION")]}),
    ("Repairing of water lines helps maintain proper flow.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 67, "SPECIALIZATION")]}),
    ("The plumber repaired a water line in the basement.", 
     {"entities": [(15, 32, "SKILLS"), (33, 53, "SERVICE"), (57, 73, "SPECIALIZATION")]}),
    ("He repaired a water lines quickly to restore water flow.", 
     {"entities": [(3, 20, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Repaired water line was inspected for proper sealing.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 62, "SPECIALIZATION")]}),
    ("The team repaired water lines in multiple locations yesterday.", 
     {"entities": [(9, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 71, "SPECIALIZATION")]}),
    #pressure testing
    ("Pressure testing is necessary to ensure proper water flow.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 60, "SPECIALIZATION")]}),
    ("Pressure testings are performed regularly during water line maintenance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 62, "SPECIALIZATION")]}),
    ("Pressure tester is used to measure the water pressure accurately.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 59, "SPECIALIZATION")]}),
    ("Pressure testers help identify leaks and weak points in pipes.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 60, "SPECIALIZATION")]}),
    ("Pressure test is done before completing a water line installation.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 57, "SPECIALIZATION")]}),
    ("Pressure tests ensure the water system functions correctly.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 58, "SPECIALIZATION")]}),
    ("Testing of water pressure is done to check pipe integrity.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 67, "SPECIALIZATION")]}),
    ("Testing of water pressures is part of routine maintenance.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 68, "SPECIALIZATION")]}),
    ("Water pressure testing ensures consistent flow throughout the system.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 67, "SPECIALIZATION")]}),
    ("Water pressure testings are performed before final inspections.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 69, "SPECIALIZATION")]}),
    ("Tested a water pressure in the main pipeline yesterday.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 65, "SPECIALIZATION")]}),
    ("Tested a water pressures to identify leaks in the system.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 66, "SPECIALIZATION")]}),
    ("Tested pressure confirmed no leaks in the newly installed pipes.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 58, "SPECIALIZATION")]}),
    ("Tested pressures were documented after maintenance completion.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 59, "SPECIALIZATION")]}),
    ("Water pressure tester was used to check for potential leaks.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 65, "SPECIALIZATION")]}),
    ("Water pressure testers ensured all connections were secure.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 66, "SPECIALIZATION")]}),
    ("Testing pressure helps maintain proper water distribution.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 60, "SPECIALIZATION")]}),
    ("Testing pressures identifies weak points in plumbing systems.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Tested pressure confirmed the integrity of the water line.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 58, "SPECIALIZATION")]}),
    ("Tested pressures revealed minor leaks requiring repair.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 59, "SPECIALIZATION")]}),

      # ----------- Water Heater Maintenance -----------   
    #sediment flushing
    ("Sediment flushing is necessary to maintain water heater efficiency.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Sediment flusher ensures proper removal of sediment from the tank.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 60, "SPECIALIZATION")]}),
    ("Sediment flushers are used during routine water heater maintenance.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Flushing sediment prevents buildup that can reduce heater performance.", 
     {"entities": [(0, 16, "SKILLS"), (17, 37, "SERVICE"), (41, 57, "SPECIALIZATION")]}),
    ("Flushing of sediment is part of standard water heater maintenance.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 64, "SPECIALIZATION")]}),
    ("Flushing of sediments removes deposits from the tank effectively.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 65, "SPECIALIZATION")]}),
    ("The plumber flushed a sediment from the water heater.", 
     {"entities": [(15, 32, "SKILLS"), (33, 53, "SERVICE"), (57, 73, "SPECIALIZATION")]}),
    ("He flushed a sediments to improve the heater's efficiency.", 
     {"entities": [(3, 20, "SKILLS"), (21, 41, "SERVICE"), (45, 61, "SPECIALIZATION")]}),
    ("Flushed sediment was inspected after maintenance.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 59, "SPECIALIZATION")]}),
    ("Flushed sediments ensured proper functioning of the water heater.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 60, "SPECIALIZATION")]}),
    #thermostat adjustment
    ("Thermostat adjustment ensures the water heater maintains the correct temperature.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 69, "SPECIALIZATION")]}),
    ("Thermostat adjustments are performed regularly to optimize performance.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 70, "SPECIALIZATION")]}),
    ("Adjusting thermostat is necessary for energy-efficient operation.", 
     {"entities": [(0, 19, "SKILLS"), (20, 40, "SERVICE"), (44, 64, "SPECIALIZATION")]}),
    ("Adjusting thermostats helps maintain consistent water temperature.", 
     {"entities": [(0, 20, "SKILLS"), (21, 41, "SERVICE"), (45, 65, "SPECIALIZATION")]}),
    ("Adjusting of thermostat ensures proper functioning of the heater.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 69, "SPECIALIZATION")]}),
    ("Adjusting of thermostats is part of standard water heater maintenance.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 70, "SPECIALIZATION")]}),
    ("The technician adjusted a thermostat to correct the temperature.", 
     {"entities": [(15, 34, "SKILLS"), (35, 55, "SERVICE"), (59, 79, "SPECIALIZATION")]}),
    ("He adjusted a thermostats to improve water heater efficiency.", 
     {"entities": [(3, 22, "SKILLS"), (23, 43, "SERVICE"), (47, 67, "SPECIALIZATION")]}),
    ("Adjusted thermostat was checked after maintenance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 66, "SPECIALIZATION")]}),
    ("Adjusted thermostats ensured consistent hot water supply.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 67, "SPECIALIZATION")]}),
      # ----------- Lighting Maintenance -----------  
    #incandescent light installation
    ("Incandescent light installation is performed by licensed electricians.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 69, "SPECIALIZATION")]}),
    ("Incandescent light installations require proper handling and wiring.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Installation of incandescent light must follow safety standards.", 
     {"entities": [(0, 35, "SKILLS"), (39, 59, "SERVICE"), (63, 74, "SPECIALIZATION")]}),
    ("Installation of incandescent lights is part of general lighting maintenance.", 
     {"entities": [(0, 36, "SKILLS"), (40, 60, "SERVICE"), (64, 75, "SPECIALIZATION")]}),
    ("Installing incandescent light ensures proper illumination.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    ("Installing incandescent lights is included in all lighting projects.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 68, "SPECIALIZATION")]}),
    ("Installing of incandescent light follows strict electrical codes.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 71, "SPECIALIZATION")]}),
    ("Installing of incandescent lights requires careful handling.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 72, "SPECIALIZATION")]}),
    ("Installed a incandescent light in the living room yesterday.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    ("Installed a incandescent lights to replace old fixtures.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 68, "SPECIALIZATION")]}),
    ("Installed incandescent light was inspected for proper wiring.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 66, "SPECIALIZATION")]}),
    ("Installed incandescent lights provided better illumination in the office.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    #flourescent light installation
    ("Fluorescent light installation is done by qualified electricians.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Fluorescent light installations require careful handling of tubes.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 71, "SPECIALIZATION")]}),
    ("Installation of fluorescent light must follow electrical safety codes.", 
     {"entities": [(0, 36, "SKILLS"), (40, 60, "SERVICE"), (64, 75, "SPECIALIZATION")]}),
    ("Installation of fluorescent lights ensures proper office illumination.", 
     {"entities": [(0, 37, "SKILLS"), (41, 61, "SERVICE"), (65, 76, "SPECIALIZATION")]}),
    ("Installing fluorescent light is part of routine lighting maintenance.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 69, "SPECIALIZATION")]}),
    ("Installing fluorescent lights helps improve workspace lighting.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Installing of fluorescent light requires proper protective gear.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 72, "SPECIALIZATION")]}),
    ("Installing of fluorescent lights is included in all lighting projects.", 
     {"entities": [(0, 34, "SKILLS"), (38, 58, "SERVICE"), (62, 73, "SPECIALIZATION")]}),
    ("Installed a fluorescent light in the conference room yesterday.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Installed a fluorescent lights to replace old fixtures in the office.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 71, "SPECIALIZATION")]}),
    ("Installed fluorescent light was inspected for proper wiring.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 69, "SPECIALIZATION")]}),
    ("Installed fluorescent lights improved overall lighting in the room.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    #led light installation
    ("LED light installation is performed to improve energy efficiency.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 64, "SPECIALIZATION")]}),
    ("LED light installations require careful handling during setup.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 65, "SPECIALIZATION")]}),
    ("Installation of LED light follows strict electrical safety codes.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 66, "SPECIALIZATION")]}),
    ("Installation of LED lights ensures consistent workspace illumination.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    ("Installing of LED light is included in standard lighting maintenance.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 68, "SPECIALIZATION")]}),
    ("Installing of LED lights improves energy efficiency and brightness.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 69, "SPECIALIZATION")]}),
    ("Installing LED light ensures proper wiring and fixture placement.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 62, "SPECIALIZATION")]}),
    ("Installing LED lights helps maintain consistent office illumination.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 63, "SPECIALIZATION")]}),
    ("Installed LED light replaced the old fluorescent fixture in the room.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 58, "SPECIALIZATION")]}),
    ("Installed LED lights improved overall lighting in the office.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 59, "SPECIALIZATION")]}),
    ("Installed a LED light was inspected for proper electrical connection.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 60, "SPECIALIZATION")]}),
    ("Installed a LED lights ensured all workspaces had proper lighting.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 61, "SPECIALIZATION")]}),
    #bulb replacement
    ("Bulb replacement is necessary to maintain proper lighting.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 55, "SPECIALIZATION")]}),
    ("Bulb replacements are performed regularly in office spaces.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 56, "SPECIALIZATION")]}),
    ("Replacing bulb helps improve lighting efficiency in rooms.", 
     {"entities": [(0, 14, "SKILLS"), (15, 35, "SERVICE"), (39, 50, "SPECIALIZATION")]}),
    ("Replacing bulbs is part of standard lighting maintenance.", 
     {"entities": [(0, 15, "SKILLS"), (16, 36, "SERVICE"), (40, 51, "SPECIALIZATION")]}),
    ("Replacing of bulb requires caution to avoid electrical hazards.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 58, "SPECIALIZATION")]}),
    ("Replacing of bulbs is included in routine maintenance tasks.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 59, "SPECIALIZATION")]}),
    ("Replacement of bulb ensures proper illumination in the office.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 59, "SPECIALIZATION")]}),
    ("Replacement of bulbs is carried out during routine lighting checks.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 60, "SPECIALIZATION")]}),
    ("Replaced a bulb in the conference room yesterday.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 53, "SPECIALIZATION")]}),
    ("Replaced a bulbs improved lighting in the main office.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 54, "SPECIALIZATION")]}),
    ("Replaced bulb was inspected for proper functionality.", 
     {"entities": [(0, 12, "SKILLS"), (16, 36, "SERVICE"), (40, 51, "SPECIALIZATION")]}),
    ("Replaced bulbs ensured consistent lighting across all workspaces.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 52, "SPECIALIZATION")]}),
    #light fixture installation
    ("Light fixture installation improves lighting in commercial spaces.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 66, "SPECIALIZATION")]}),
    ("Light fixture installations are performed to enhance interior lighting.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    ("Installation of light fixture must follow electrical safety standards.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Installation of light fixtures ensures proper illumination in offices.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 71, "SPECIALIZATION")]}),
    ("Installing of light fixture is included in all lighting maintenance tasks.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 68, "SPECIALIZATION")]}),
    ("Installing of light fixtures helps improve overall workspace lighting.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 69, "SPECIALIZATION")]}),
    ("Installing light fixture requires careful alignment and wiring.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 62, "SPECIALIZATION")]}),
    ("Installing light fixtures ensures consistent lighting throughout the office.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 63, "SPECIALIZATION")]}),
    ("Installed light fixture replaced the old unit in the conference room.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 61, "SPECIALIZATION")]}),
    ("Installed light fixtures improved lighting across all work areas.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 62, "SPECIALIZATION")]}),
    ("Installed a light fixture was inspected for correct electrical connection.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 64, "SPECIALIZATION")]}),

      # ----------- Electrical Wiring and Rewiring ----------- 
    #wire installation
    ("Wire installation is essential for safe electrical wiring.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 55, "SPECIALIZATION")]}),
    ("Wire installations require certified electricians for proper setup.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 56, "SPECIALIZATION")]}),
    ("Installation of wire must follow electrical safety regulations.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 59, "SPECIALIZATION")]}),
    ("Installation of wires ensures proper connectivity in circuits.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 60, "SPECIALIZATION")]}),
    ("Installing of wire helps complete the circuit installation.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 59, "SPECIALIZATION")]}),
    ("Installing of wires is included in all electrical maintenance tasks.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 60, "SPECIALIZATION")]}),
    ("Installing wire requires careful measurement and routing.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 53, "SPECIALIZATION")]}),
    ("Installing wires ensures proper connection between components.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 54, "SPECIALIZATION")]}),
    ("Installed wire was inspected to confirm correct connections.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 51, "SPECIALIZATION")]}),
    ("Installed wires improved the circuit performance in the building.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 52, "SPECIALIZATION")]}),
    ("Installed a wire ensured continuity throughout the electrical system.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 54, "SPECIALIZATION")]}),
    ("Installed a wires replaced faulty connections in the main panel.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 55, "SPECIALIZATION")]}),
    #conduit installation
    ("Conduit installation ensures safe routing of electrical wiring.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 59, "SPECIALIZATION")]}),
    ("Conduit installations are required in all new electrical setups.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 60, "SPECIALIZATION")]}),
    ("Installation of conduit must follow electrical safety standards.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 63, "SPECIALIZATION")]}),
    ("Installation of conduits ensures organized and safe wiring.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 64, "SPECIALIZATION")]}),
    ("Installing of conduit helps protect wires from physical damage.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 61, "SPECIALIZATION")]}),
    ("Installing of conduits is part of standard electrical installation tasks.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 62, "SPECIALIZATION")]}),
    ("Installing conduit requires accurate measurement and placement.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 56, "SPECIALIZATION")]}),
    ("Installing conduits ensures proper wiring layout in buildings.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 57, "SPECIALIZATION")]}),
    ("Installed conduit was checked for proper alignment and security.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 56, "SPECIALIZATION")]}),
    ("Installed conduits improved overall wiring safety in the facility.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 57, "SPECIALIZATION")]}),
    ("Installed a conduit replaced the old, damaged conduit in the wall.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 58, "SPECIALIZATION")]}),
    ("Installed a conduits ensured secure electrical connections throughout the building.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 59, "SPECIALIZATION")]}),
    #electrical insulation
    ("Electrical insulation prevents short circuits and enhances safety.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 60, "SPECIALIZATION")]}),
    ("Insulation of electrical wiring is essential for all wiring projects.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 69, "SPECIALIZATION")]}),
    ("Insulation of electrical wirings ensures proper protection of circuits.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Insulating electrical wiring is part of routine electrical maintenance.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    ("Insulating electrical wirings prevents electrical hazards in buildings.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 68, "SPECIALIZATION")]}),
    ("Insulating of electrical wiring helps maintain circuit integrity.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 70, "SPECIALIZATION")]}),
    ("Insulating of electrical wirings ensures safety and compliance.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 71, "SPECIALIZATION")]}),
    ("Insulated a electrical wiring was checked for proper coverage.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    ("Insulated a electrical wirings improved overall circuit safety.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 68, "SPECIALIZATION")]}),
    ("Insulated electrical wiring prevents energy loss in the system.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 66, "SPECIALIZATION")]}),
    ("Insulated electrical wirings were tested for proper functionality.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 67, "SPECIALIZATION")]}),
    #circuit connection
    ("Circuit connection ensures proper flow of electricity in systems.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 57, "SPECIALIZATION")]}),
    ("Circuit connections are inspected regularly to maintain electrical safety.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 58, "SPECIALIZATION")]}),
    ("Connecting circuit requires careful handling to avoid short circuits.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 57, "SPECIALIZATION")]}),
    ("Connecting circuits is part of standard electrical installation procedures.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 58, "SPECIALIZATION")]}),
    ("Connecting of circuit ensures all components are properly linked.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 61, "SPECIALIZATION")]}),
    ("Connecting of circuits improves safety and reduces the risk of faults.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 62, "SPECIALIZATION")]}),
    ("Connection of circuit must follow safety and wiring standards.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 61, "SPECIALIZATION")]}),
    ("Connection of circuits ensures proper network distribution in the panel.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 62, "SPECIALIZATION")]}),
    ("Connected a circuit was tested for continuity and performance.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 59, "SPECIALIZATION")]}),
    ("Connected a circuits improved overall electrical network reliability.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 60, "SPECIALIZATION")]}),
    ("Connected circuit replaced the faulty connection in the system.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 56, "SPECIALIZATION")]}),
    ("Connected circuits ensured proper electricity distribution throughout.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 57, "SPECIALIZATION")]}),

      # ----------- Washing Machine Maintenance ----------- 
    #washing machine repair
    ("Washing machine repair is essential to maintain appliance performance.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 69, "SPECIALIZATION")]}),
    ("Washing machine repairs are performed regularly to prevent breakdowns.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 70, "SPECIALIZATION")]}),
    ("Repairing washing machine helps restore proper function to the appliance.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 70, "SPECIALIZATION")]}),
    ("Repairing washing machines is part of routine appliance maintenance.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 71, "SPECIALIZATION")]}),
    ("Repairing of washing machine requires careful diagnosis of faults.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 73, "SPECIALIZATION")]}),
    ("Repairing of washing machines ensures proper operation of all components.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Repaired washing machines restored proper washing cycles in the unit.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 70, "SPECIALIZATION")]}),
    ("Repaired a washing machine resolved the persistent leakage issue.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 71, "SPECIALIZATION")]}),
    ("Repaired a washing machines improved appliance efficiency.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 72, "SPECIALIZATION")]}),
    #belt replacement
    ("Belt replacement ensures proper operation of washing machines.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 64, "SPECIALIZATION")]}),

    ("Belt replacements are conducted to maintain appliance efficiency.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 65, "SPECIALIZATION")]}),

    # “Replacement of …” variant
    ("Replacement of belt restores correct functioning of the washing machine.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 68, "SPECIALIZATION")]}),
    ("Replacement of belts prevents slippage and mechanical failure.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 69, "SPECIALIZATION")]}),
    ("Replacement of washing machine belt ensures smooth washing cycles.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 79, "SPECIALIZATION")]}),
    ("Replacement of washing machine belts improves overall appliance performance.", 
     {"entities": [(0, 34, "SKILLS"), (38, 58, "SERVICE"), (62, 80, "SPECIALIZATION")]}),
    ("Replacing washing machine belt is part of routine maintenance.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Replacing washing machine belts helps maintain appliance efficiency.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 75, "SPECIALIZATION")]}),
    ("Replacing of washing machine belt requires proper alignment and tension.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 78, "SPECIALIZATION")]}),
    ("Replacing of washing machine belts ensures smooth operation.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 79, "SPECIALIZATION")]}),
    ("Replacing belt is necessary when it shows signs of wear.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 62, "SPECIALIZATION")]}),
    ("Replacing belts prevents machine malfunction and downtime.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 63, "SPECIALIZATION")]}),
    ("Replacing of belt requires careful removal and fitting.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 67, "SPECIALIZATION")]}),
    ("Replacing of belts ensures all washing machine components function properly.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 68, "SPECIALIZATION")]}),
    ("Replaced a washing machine belt restored proper operation.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Replaced a washing machine belts improved appliance efficiency.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 75, "SPECIALIZATION")]}),
    ("Replaced washing machine belt prevented slippage during operation.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 73, "SPECIALIZATION")]}),
    ("Replaced washing machine belts ensured smooth and reliable cycles.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    #drum cleaning
    ("Drum cleaning is essential to maintain washing machine hygiene.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 59, "SPECIALIZATION")]}),
    ("Cleaning drum prevents buildup of detergent residues in appliances.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 59, "SPECIALIZATION")]}),
    ("Cleaning drums ensures proper washing performance and longevity.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 60, "SPECIALIZATION")]}),
    ("Cleaned drum restored proper hygiene and functionality.", 
     {"entities": [(0, 12, "SKILLS"), (16, 36, "SERVICE"), (40, 58, "SPECIALIZATION")]}),
    ("Cleaned drums improved washing machine efficiency and performance.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 59, "SPECIALIZATION")]}),
    ("Cleaned washing machine drum removed buildup and odor effectively.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 70, "SPECIALIZATION")]}),
    ("Cleaned washing machine drums ensured all components functioned properly.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 71, "SPECIALIZATION")]}),
    ("Cleaned a washing machine drum restored full washing capacity.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 72, "SPECIALIZATION")]}),
    ("Cleaned a washing machine drums prevented mold and mildew buildup.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 73, "SPECIALIZATION")]}),
    ("Washing machine drum cleaning is part of routine maintenance.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 72, "SPECIALIZATION")]}),
    ("Cleaning of washing machine drum ensures proper hygiene.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Cleaning of washing machine drums prevents odor and residue buildup.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 75, "SPECIALIZATION")]}),
    ("Cleaning of drum maintains appliance performance and longevity.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 62, "SPECIALIZATION")]}),
    ("Cleaning of drums is performed regularly to avoid buildup.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 63, "SPECIALIZATION")]}),
    ("Cleaned a drum removed all residues and maintained proper hygiene.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 61, "SPECIALIZATION")]}),
    ("Cleaned a drums improved washing efficiency and hygiene.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 62, "SPECIALIZATION")]}),
    #hose replacement
    ("Hose replacement ensures proper water flow in the washing machine.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 62, "SPECIALIZATION")]}),
    ("Hose replacements prevent leaks and maintain appliance efficiency.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 63, "SPECIALIZATION")]}),
    ("Replacing hose restores proper water circulation in the system.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 61, "SPECIALIZATION")]}),
    ("Replacing hoses prevents water leakage and ensures smooth operation.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 62, "SPECIALIZATION")]}),
    ("Replacing of hose is necessary when wear and tear is observed.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 66, "SPECIALIZATION")]}),
    ("Replacing of hoses ensures all washing machine components function properly.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 67, "SPECIALIZATION")]}),
    ("Replacing of washing machine hose prevents leaks and flooding.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 77, "SPECIALIZATION")]}),
    ("Replacing of washing machine hoses improves water flow and washing efficiency.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 78, "SPECIALIZATION")]}),
    ("Replacement of washing machine hose is part of routine maintenance.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 79, "SPECIALIZATION")]}),
    ("Replacement of washing machine hoses prevents leaks and damages.", 
     {"entities": [(0, 34, "SKILLS"), (38, 58, "SERVICE"), (62, 80, "SPECIALIZATION")]}),
    ("Replacement of hose ensures proper water flow and machine safety.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 69, "SPECIALIZATION")]}),
    ("Replacement of hoses improves washing machine longevity.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 70, "SPECIALIZATION")]}),
    #washing machine hose installation
    ("Washing machine hose installation is essential for proper water flow.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 79, "SPECIALIZATION")]}),
    ("Washing machine hose installations prevent leaks and ensure smooth operation.", 
     {"entities": [(0, 34, "SKILLS"), (38, 58, "SERVICE"), (62, 80, "SPECIALIZATION")]}),
    ("Installation of washing machine hose ensures proper connection and function.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Installation of washing machine hoses prevents leakage and flooding.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 75, "SPECIALIZATION")]}),
    ("Installment of washing machine hose is part of routine maintenance.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 76, "SPECIALIZATION")]}),
    ("Installment of washing machine hoses ensures proper appliance function.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 77, "SPECIALIZATION")]}),
    ("Installing washing machine hose requires careful handling to avoid leaks.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Installing washing machine hoses improves water flow and appliance efficiency.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 75, "SPECIALIZATION")]}),
    ("Installed washing machine hose restored proper water circulation in the unit.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 73, "SPECIALIZATION")]}),
    ("Installed washing machine hoses prevented leakage during washing cycles.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 74, "SPECIALIZATION")]}),
    ("Installed a washing machine hose ensured correct water connection.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 76, "SPECIALIZATION")]}),
    ("Installed a washing machine hoses improved machine performance and safety.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 77, "SPECIALIZATION")]}),

      # ----------- Television Maintenance -----------
    #screen replacement
    ("Screen replacement is essential for restoring television display clarity.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Screen replacements prevent malfunction and improve viewing experience.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),
    ("Replacing screen fixes cracks and display issues effectively.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 64, "SPECIALIZATION")]}),
    ("Replacing screens ensures optimal image quality and performance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 65, "SPECIALIZATION")]}),
    ("Replacing of screen is done to maintain television functionality.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Replacing of screens prevents further damage to TV panels.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),
    ("Replaced a screen restored proper display and resolution.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 66, "SPECIALIZATION")]}),
    ("Replaced a screens improved television clarity and performance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Replaced screen fixed the broken panel efficiently.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 63, "SPECIALIZATION")]}),
    ("Replaced screens ensured better image quality for the TV.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 64, "SPECIALIZATION")]}),
    ("Replacement of screen is necessary when cracks appear.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 70, "SPECIALIZATION")]}),
    ("Replacement of screens ensures consistent television performance.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 71, "SPECIALIZATION")]}),
    #screen repair
    ("Screen repair restores the television display to optimal quality.", 
     {"entities": [(0, 12, "SKILLS"), (16, 36, "SERVICE"), (40, 61, "SPECIALIZATION")]}),
    ("Screen repairing fixes broken pixels and damaged panels effectively.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 65, "SPECIALIZATION")]}),
    ("Repairing screen improves display performance and clarity.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 65, "SPECIALIZATION")]}),
    ("Repairing screens ensures proper functioning of all display components.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 66, "SPECIALIZATION")]}),
    ("Repairing of screen is necessary when there are cracks or dead pixels.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),
    ("Repairing of screens prevents further damage and maintains image quality.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 69, "SPECIALIZATION")]}),
    ("Repaired a screen restored proper display and resolution.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 66, "SPECIALIZATION")]}),
    ("Repaired a screens improved television clarity and performance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Repaired screen fixed all display issues efficiently.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 62, "SPECIALIZATION")]}),
    ("Repaired screens ensured proper image quality for the television.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 63, "SPECIALIZATION")]}),
    #remote sensore repair
    ("Remote sensor repair ensures proper functioning of the TV control system.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 70, "SPECIALIZATION")]}),
    ("Remote sensor repairs prevent connectivity issues with the television.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 71, "SPECIALIZATION")]}),
    ("Remote sensor repairing restores accurate signal reception.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 74, "SPECIALIZATION")]}),
    ("Repairing remote sensor ensures the TV responds to commands correctly.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 71, "SPECIALIZATION")]}),
    ("Repairing remote sensors prevents control issues and malfunction.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 72, "SPECIALIZATION")]}),
    ("Repairing of remote sensor restores proper communication with the device.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 75, "SPECIALIZATION")]}),
    ("Repairing of remote sensors prevents lag in remote operation.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 76, "SPECIALIZATION")]}),
    ("Repaired a remote sensor restored proper TV control.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 72, "SPECIALIZATION")]}),
    ("Repaired a remote sensors improved device response accuracy.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 73, "SPECIALIZATION")]}),
    ("Repaired remote sensor fixed all connectivity issues.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 71, "SPECIALIZATION")]}),
    ("Repaired remote sensors ensured proper operation of all controls.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 72, "SPECIALIZATION")]}),
    #power supply board repair
    ("Power supply board repair is crucial for proper television operation.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 75, "SPECIALIZATION")]}),
    ("Power supply board repairs prevent voltage fluctuations and device damage.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 76, "SPECIALIZATION")]}),
    ("Power supply board repairing fixes electrical faults efficiently.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 78, "SPECIALIZATION")]}),
    ("Repairing power supply board ensures stable device performance.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 77, "SPECIALIZATION")]}),
    ("Repairing power supply boards prevents TV malfunctions.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 78, "SPECIALIZATION")]}),
    ("Repairing of power supply board restores full device functionality.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 82, "SPECIALIZATION")]}),
    ("Repairing of power supply boards improves television reliability.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 83, "SPECIALIZATION")]}),
    ("Repaired a power supply board fixed all voltage issues.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 79, "SPECIALIZATION")]}),
    ("Repaired a power supply boards restored full device operation.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 80, "SPECIALIZATION")]}),
    ("Repaired power supply board ensured proper television performance.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 76, "SPECIALIZATION")]}),
    ("Repaired power supply boards prevented further device damage.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 77, "SPECIALIZATION")]}),
    #control panel troubleshooting
    ("Control panel troubleshooting ensures proper operation of the device.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 78, "SPECIALIZATION")]}),
    ("Troubleshooting control panel fixes all input and output issues.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 78, "SPECIALIZATION")]}),
    ("Troubleshooting control panels prevents system errors and malfunctions.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 79, "SPECIALIZATION")]}),
    ("Troubleshooting of control panel restores full functionality.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 81, "SPECIALIZATION")]}),
    ("Troubleshooting of control panels improves device reliability.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 82, "SPECIALIZATION")]}),
    ("Troubleshoot control panel prevents recurring errors efficiently.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 77, "SPECIALIZATION")]}),
    ("Troubleshoot control panels ensures smooth operation of all functions.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 78, "SPECIALIZATION")]}),
    ("Troubleshot control panel restored proper device performance.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 78, "SPECIALIZATION")]}),
    ("Troubleshot control panels fixed recurring errors and malfunctions.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 79, "SPECIALIZATION")]}),
    ("Troubleshot a control panel ensured correct input and output signals.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 81, "SPECIALIZATION")]}),
    ("Troubleshot a control panels prevented future system failures.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 82, "SPECIALIZATION")]}),
    #backlight replacement
    ("Backlight replacement restores screen brightness to optimal levels.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 69, "SPECIALIZATION")]}),
    ("Backlight replacements prevent uneven lighting and screen dimming.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 70, "SPECIALIZATION")]}),
    ("Replacing backlight improves display illumination and clarity.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 66, "SPECIALIZATION")]}),
    ("Replacing backlights ensures consistent screen brightness across the panel.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Replacing of backlight is necessary when brightness fades.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 71, "SPECIALIZATION")]}),
    ("Replacing of backlights maintains optimal screen performance.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 72, "SPECIALIZATION")]}),
    ("Replaced a backlight restored proper display brightness.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 70, "SPECIALIZATION")]}),
    ("Replaced a backlights fixed dim areas on the screen.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 71, "SPECIALIZATION")]}),
    ("Replaced backlight improved display clarity and visibility.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Replaced backlights restored uniform illumination across the TV.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),
    ("Replacement of backlight is essential for proper screen function.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 74, "SPECIALIZATION")]}),
    ("Replacement of backlights prevents uneven lighting and flickering.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 75, "SPECIALIZATION")]}),
    #backlight repair
    ("Backlight repair fixes dim or flickering screens effectively.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Backlight repairs restore proper brightness across the display.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),
    ("Repairing backlight ensures consistent illumination for the TV.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Repairing backlights fixes uneven lighting on the screen.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),
    ("Repairing of backlight prevents further dimming and flickering.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 71, "SPECIALIZATION")]}),
    ("Repairing of backlights maintains optimal display brightness.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 72, "SPECIALIZATION")]}),
    ("Repaired a backlight fixed the dim areas on the screen.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 70, "SPECIALIZATION")]}),
    ("Repaired a backlights restored proper illumination across the TV.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 71, "SPECIALIZATION")]}),
    ("Repaired backlight improved display brightness and clarity.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 67, "SPECIALIZATION")]}),
    ("Repaired backlights fixed flickering and dimming issues effectively.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 68, "SPECIALIZATION")]}),

      # ----------- Electric Fan Maintenance -----------
    #motor cleaning
    ("Motor cleaning removes accumulated dust for optimal fan performance.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 64, "SPECIALIZATION")]}),
    ("Cleaning motor ensures smooth operation and reduces noise.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 64, "SPECIALIZATION")]}),
    ("Cleaning motors prevents overheating and prolongs fan life.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 65, "SPECIALIZATION")]}),
    ("Cleaned motor restored proper airflow and reduced vibrations.", 
     {"entities": [(0, 12, "SKILLS"), (16, 36, "SERVICE"), (40, 63, "SPECIALIZATION")]}),
    ("Cleaned motors removed dust and improved efficiency.", 
     {"entities": [(0, 13, "SKILLS"), (17, 37, "SERVICE"), (41, 64, "SPECIALIZATION")]}),
    ("Cleaned a motor ensured smooth and silent operation.", 
     {"entities": [(0, 14, "SKILLS"), (18, 38, "SERVICE"), (42, 65, "SPECIALIZATION")]}),
    ("Cleaned a motors prevented overheating and motor damage.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 66, "SPECIALIZATION")]}),
    ("Cleaning of motor maintains optimal performance of the fan.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 67, "SPECIALIZATION")]}),
    ("Cleaning of motors reduces wear and tear on fan components.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 68, "SPECIALIZATION")]}),
    #motor lubrication
    ("Motor lubrication ensures smooth rotation and prevents wear.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 68, "SPECIALIZATION")]}),
    ("Lubrication of motor reduces friction and prolongs motor life.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 70, "SPECIALIZATION")]}),
    ("Lubrication of motors maintains efficient fan performance.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 71, "SPECIALIZATION")]}),
    ("Lubricated motor restored smooth operation and minimized noise.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 66, "SPECIALIZATION")]}),
    ("Lubricated motors improved rotation efficiency and reduced wear.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 67, "SPECIALIZATION")]}),
    ("Lubricated a motor ensured quiet and smooth functioning.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 68, "SPECIALIZATION")]}),
    ("Lubricated a motors prevented friction-related damage.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 69, "SPECIALIZATION")]}),
    #blade replacement
    ("Blade replacement ensures optimal airflow from the electric fan.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 67, "SPECIALIZATION")]}),
    ("Blade replacements prevent imbalanced rotation and fan noise.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 68, "SPECIALIZATION")]}),
    ("Replacing blade maintains smooth operation and consistent airflow.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 66, "SPECIALIZATION")]}),
    ("Replacing blades improves fan efficiency and reduces vibrations.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 67, "SPECIALIZATION")]}),
    ("Replacing of blade prevents wear and ensures long-lasting performance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 68, "SPECIALIZATION")]}),
    ("Replacing of blades maintains balance and optimal airflow.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 69, "SPECIALIZATION")]}),
    ("Replaced a blade restored proper rotation and balanced airflow.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 68, "SPECIALIZATION")]}),
    ("Replaced a blades fixed wobbling and improved fan performance.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 69, "SPECIALIZATION")]}),
    ("Replaced blade ensured smooth operation and efficient airflow.", 
     {"entities": [(0, 15, "SKILLS"), (19, 39, "SERVICE"), (43, 65, "SPECIALIZATION")]}),
    ("Replaced blades prevented imbalance and reduced fan noise.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 66, "SPECIALIZATION")]}),
    ("Replacement of blade is necessary for optimal fan performance.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 71, "SPECIALIZATION")]}),
    ("Replacement of blades maintains balance and smooth airflow.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 72, "SPECIALIZATION")]}),
    #oscillation meechanism repair
    ("Oscillation mechanism repair restores smooth side-to-side movement.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Oscillation mechanism repairs prevent jerky movements and imbalance.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Repairing oscillation mechanism ensures consistent fan rotation.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Repairing oscillation mechanisms maintains smooth oscillatory motion.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Repairing of oscillation mechanism fixes wobbling and uneven rotation.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Repairing of oscillation mechanisms prevents mechanical wear and tear.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Repaired a oscillation mechanism restored smooth fan movement.", 
     {"entities": [(0, 31, "SKILLS"), (35, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Repaired a oscillation mechanisms fixed jerky motion and imbalance.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Repaired oscillation mechanism improved side-to-side operation.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Repaired oscillation mechanisms restored proper oscillatory function.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    #speed control repair
    ("Speed control repair ensures consistent fan speed and smooth operation.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Speed control repairs prevent sudden speed changes and uneven rotation.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Speed controller repair maintains proper voltage regulation for fans.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Speed controller repairs prevent malfunction and ensure smooth operation.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repairing speed control maintains steady fan rotation and performance.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repairing speed controls ensures proper adjustment of fan speed.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repairing speed controller prevents speed fluctuation and noise.", 
     {"entities": [(0, 26, "SKILLS"), (30, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repairing speed controllers maintains consistent airflow and performance.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repairing of speed control fixes irregular speed issues effectively.", 
     {"entities": [(0, 29, "SKILLS"), (33, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Repairing of speed controls restores proper fan speed adjustment.", 
     {"entities": [(0, 30, "SKILLS"), (34, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Repairing of speed controller prevents motor damage due to overspeed.", 
     {"entities": [(0, 32, "SKILLS"), (36, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Repairing of speed controllers ensures smooth and safe operation.", 
     {"entities": [(0, 33, "SKILLS"), (37, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Repaired a speed control restored stable fan operation.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repaired a speed controls fixed inconsistent speed issues.", 
     {"entities": [(0, 25, "SKILLS"), (29, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Repaired a speed controller improved fan performance and consistency.", 
     {"entities": [(0, 27, "SKILLS"), (31, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repaired a speed controllers prevented motor damage and imbalance.", 
     {"entities": [(0, 28, "SKILLS"), (32, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Repaired speed control ensured proper speed regulation.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Repaired speed controls maintained smooth and even rotation.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Repaired speed controller fixed erratic fan speed efficiently.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repaired speed controllers restored consistent motor performance.", 
     {"entities": [(0, 24, "SKILLS"), (28, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    #bearing replacement
    ("Bearing replacement ensures smooth rotation and reduces fan noise.", 
     {"entities": [(0, 19, "SKILLS"), (23, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Bearing replacements prevent wear and prolong motor life.", 
     {"entities": [(0, 20, "SKILLS"), (24, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Replacing bearing maintains consistent fan operation and efficiency.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Replacing bearings restores smooth airflow and reduces vibrations.", 
     {"entities": [(0, 18, "SKILLS"), (22, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Replacing of bearing prevents motor friction and imbalance.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replacing of bearings ensures proper rotation and fan stability.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replaced a bearing restored smooth fan rotation and performance.", 
     {"entities": [(0, 21, "SKILLS"), (25, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replaced a bearings fixed uneven rotation and reduced noise.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replaced bearing improved fan stability and motor efficiency.", 
     {"entities": [(0, 16, "SKILLS"), (20, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Replaced bearings restored balanced rotation and smooth operation.", 
     {"entities": [(0, 17, "SKILLS"), (21, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Replacement of bearing ensures smooth motor performance.", 
     {"entities": [(0, 22, "SKILLS"), (26, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replacement of bearings prevents imbalance and prolongs fan life.", 
     {"entities": [(0, 23, "SKILLS"), (27, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),

      # ----------- Refrigerator Maintenance -----------
    #condenser coil cleaning
    ("Condenser coil cleaning improves refrigerator efficiency and cooling.", 
     {"entities": [(0, 25, "SKILLS"), (29, 52, "SERVICE"), (56, 77, "SPECIALIZATION")]}),
    ("Cleaning condenser coil removes dust and enhances cooling performance.", 
     {"entities": [(0, 22, "SKILLS"), (26, 49, "SERVICE"), (53, 74, "SPECIALIZATION")]}),
    ("Cleaning condenser coils ensures proper heat dissipation.", 
     {"entities": [(0, 23, "SKILLS"), (27, 50, "SERVICE"), (54, 75, "SPECIALIZATION")]}),
    ("Cleaned condenser coil restored refrigerator cooling efficiency.", 
     {"entities": [(0, 21, "SKILLS"), (25, 48, "SERVICE"), (52, 73, "SPECIALIZATION")]}),
    ("Cleaned condenser coils removed dust and improved refrigerator performance.", 
     {"entities": [(0, 22, "SKILLS"), (26, 49, "SERVICE"), (53, 74, "SPECIALIZATION")]}),
    ("Cleaned refrigerator condenser coil ensured optimal cooling.", 
     {"entities": [(0, 31, "SKILLS"), (35, 58, "SERVICE"), (62, 83, "SPECIALIZATION")]}),
    ("Cleaned refrigerator condenser coils maintained efficient heat exchange.", 
     {"entities": [(0, 32, "SKILLS"), (36, 59, "SERVICE"), (63, 84, "SPECIALIZATION")]}),
    ("Cleaning of refrigerator condenser coil prevents frost buildup.", 
     {"entities": [(0, 36, "SKILLS"), (40, 63, "SERVICE"), (67, 88, "SPECIALIZATION")]}),
    ("Cleaning of refrigerator condenser coils maintains optimal refrigerator performance.", 
     {"entities": [(0, 37, "SKILLS"), (41, 64, "SERVICE"), (68, 89, "SPECIALIZATION")]}),
    #defrost system maintenance
    ("Defrost system maintenance prevents ice buildup and ensures proper cooling.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 83, "SPECIALIZATION")]}),
    ("Maintenance of defrost system keeps the refrigerator operating efficiently.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 84, "SPECIALIZATION")]}),
    ("Maintenance of defrost systems ensures uniform cooling throughout the fridge.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 85, "SPECIALIZATION")]}),
    ("Maintaining defrost system prevents frost accumulation and motor strain.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 81, "SPECIALIZATION")]}),
    ("Maintaining defrost systems ensures consistent refrigerator performance.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 82, "SPECIALIZATION")]}),
    ("Maintaining of defrost system avoids ice formation and enhances cooling.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 85, "SPECIALIZATION")]}),
    ("Maintaining of defrost systems keeps the refrigerator frost-free and efficient.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 86, "SPECIALIZATION")]}),
    ("Maintained defrost system restored proper cooling and reduced ice buildup.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 80, "SPECIALIZATION")]}),
    ("Maintained defrost systems prevented frost accumulation and improved efficiency.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 81, "SPECIALIZATION")]}),
    ("Maintained a defrost system ensured even cooling and optimal refrigerator performance.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 83, "SPECIALIZATION")]}),
    ("Maintained a defrost systems kept the fridge frost-free and running smoothly.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 84, "SPECIALIZATION")]}),
    #thermostat control checking
    ("Thermostat control checking ensures the refrigerator maintains the correct temperature.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 84, "SPECIALIZATION")]}),
    ("Checking thermostat control prevents temperature fluctuations and keeps food fresh.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 84, "SPECIALIZATION")]}),
    ("Checking thermostat controls ensures consistent cooling throughout the refrigerator.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 85, "SPECIALIZATION")]}),
    ("Checking of thermostat control maintains proper fridge temperature and efficiency.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 87, "SPECIALIZATION")]}),
    ("Checking of thermostat controls prevents cooling errors and improves refrigerator performance.", 
     {"entities": [(0, 31, "SKILLS"), (35, 60, "SERVICE"), (64, 88, "SPECIALIZATION")]}),
    ("Checked a thermostat control restored proper temperature and efficient cooling.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 83, "SPECIALIZATION")]}),
    ("Checked a thermostat controls ensured uniform temperature throughout the refrigerator.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 84, "SPECIALIZATION")]}),
    ("Checked thermostat control fixed temperature inconsistencies effectively.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 81, "SPECIALIZATION")]}),
    ("Checked thermostat controls maintained optimal refrigerator cooling performance.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 82, "SPECIALIZATION")]}),
    #ice maker repair
    ("Ice maker repair ensures proper ice production and prevents leakage.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Ice maker repairs restore the functionality of the refrigerator's ice system.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repairing ice maker fixes malfunctions and improves ice quality.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repairing ice makers ensures consistent ice production and prevents clogs.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repairing of ice maker prevents freezing issues and maintains performance.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repairing of ice makers restores proper ice maker operation and efficiency.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repaired a ice maker fixed ice production and eliminated leaks.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Repaired a ice makers restored ice production consistency.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repaired ice maker improved ice quality and refrigerator performance.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repaired ice makers maintained proper ice output and prevented jams.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
      # ----------- Air Conditioner Maintenance -----------     
    #air conditioner repair
    ("Air conditioner repair fixes cooling issues and restores room comfort.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),

    ("Air conditioner repairs maintain optimal performance and prevent breakdowns.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),

    ("Repairs air conditioner ensure consistent cooling and energy efficiency.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),

    ("Repairs air conditioners prevent malfunction and restore proper airflow.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),

    ("Repairs a air conditioner keeps the system running smoothly and efficiently.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),

    ("Repairs a air conditioners restore cooling performance and prevent failures.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),

    # Present continuous / gerund
    ("Repairing air conditioner fixes leaks and restores optimal cooling.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Repairing air conditioners ensures consistent performance and prevents breakdowns.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Repairing of air conditioner restores airflow and maintains cooling efficiency.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),
    ("Repairing of air conditioners prevents malfunctions and optimizes system performance.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Repaired a air conditioner restored proper cooling and eliminated faults.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Repaired a air conditioners fixed airflow issues and improved efficiency.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Repaired air conditioner maintained optimal temperature and prevented failures.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Repaired air conditioners restored consistent cooling throughout the room.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    #air conditioner installation
    ("Air conditioner installation ensures proper setup and efficient cooling.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Air conditioner installations maintain reliable operation and optimal airflow.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Installing air conditioner provides correct placement and improves cooling efficiency.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Installing air conditioners ensures effective system performance and airflow.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Installing of air conditioner guarantees proper cooling and efficient installation.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Installing of air conditioners prevents installation errors and ensures optimal performance.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),
    ("Installed a air conditioner restored proper airflow and cooling performance.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Installed a air conditioners ensured correct placement and reliable operation.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Installed air conditioner improved system efficiency and room cooling.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Installed air conditioners restored consistent airflow and prevented malfunctions.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    #coil cleaning 
    ("Coil cleaning prevents dust accumulation and improves air conditioner efficiency.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Air conditioning coil cleaning ensures optimal cooling and prevents overheating.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Cleaning coil restores proper airflow and enhances air conditioner performance.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Cleaning coils removes dust and maintains the efficiency of the air conditioner.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Air conditioner coil cleaning guarantees proper heat exchange and airflow.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Cleaning of air conditioning coil prevents blockages and maintains cooling efficiency.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Cleaned coil restored optimal airflow and improved air conditioner performance.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Cleaned coils removed dust buildup and enhanced air conditioner cooling.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Cleaned air conditioning coil ensured efficient operation and prevented clogs.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Cleaned a air conditioner coil restored proper cooling and improved airflow.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Cleaning of air conditioner coils maintains optimal heat exchange and system efficiency.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Cleaning a air conditioning coils ensures consistent airflow and prevents dust buildup.", 
     {"entities": [(0, 32, "SKILLS"), (36, 61, "SERVICE"), (65, 90, "SPECIALIZATION")]}),
    #filter clearning
    ("Filter cleaning ensures clean airflow and maintains air conditioner efficiency.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Air conditioner filter cleaning prevents clogging and improves cooling performance.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Cleaning filter removes dust and ensures proper air circulation in the AC system.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Cleaning filters restores airflow and maintains optimal performance of the air conditioner.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Cleaned filter restored proper airflow and improved AC efficiency.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Cleaned filters removed accumulated dust and enhanced air conditioner performance.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Cleaned air conditioner filter ensured optimal airflow and prevented blockages.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Cleaned a air conditioner filter restored consistent cooling and improved efficiency.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Cleaning of air conditioner filter prevents clogging and maintains system efficiency.", 
     {"entities": [(0, 31, "SKILLS"), (35, 60, "SERVICE"), (64, 89, "SPECIALIZATION")]}),
    ("Cleaning a air conditioner filter restores airflow and ensures proper cooling.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),

      # ----------- Sofa Maintenance -----------
    #cushion replacement
    ("Cushion replacement restores comfort and maintains sofa appearance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Cushion replacements ensure proper support and extend sofa lifespan.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Replacing cushion improves seating comfort and prevents sagging.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replacing cushions restores sofa shape and enhances overall support.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Replacing of cushion prevents wear and maintains seating comfort.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Replacing of cushions ensures proper cushion alignment and sofa durability.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Replacing of furniture cushion restores original comfort and support.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),
    ("Replacing of furniture cushions improves seating experience and maintains sofa quality.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    #cushion repair
    ("Cushion repair restores torn fabric and maintains sofa comfort.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Cushion repairs fix worn-out cushions and ensure proper seating support.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Repairing cushion strengthens damaged areas and improves comfort.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repairing cushions restores proper shape and prolongs sofa life.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repairing of cushion fixes internal stuffing and enhances comfort.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repairing of cushions strengthens fabric and maintains sofa support.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repaired a cushion restored proper shape and improved seating comfort.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repaired a cushions fixed tears and strengthened support for the sofa.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repaired cushions restored cushioning and enhanced comfort for seating.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    #frame reinforcement
    ("Frame reinforcement strengthens the sofa structure and ensures durability.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Frame reinforcements prevent sagging and maintain sofa integrity.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Reinforcing frame stabilizes the sofa and extends its lifespan.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Reinforcing frames ensures proper support and improves seating comfort.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Reinforcing of frame strengthens joints and enhances sofa durability.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Reinforcing of frames improves stability and maintains structural support.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Reinforced a frame restored sofa stability and ensured proper support.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Reinforced a frames strengthened the sofa and prevented sagging.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Reinforced frame enhanced sofa durability and improved seating comfort.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Reinforced frames stabilized the structure and extended sofa lifespan.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    #upholstery cleaning 
    ("Upholstery cleaning removes stains and maintains sofa appearance.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Upholsteries cleaning ensures fabric hygiene and prolongs sofa lifespan.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Cleaning upholstery restores fabric texture and improves sofa comfort.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Cleaning upholsteries removes dirt and ensures proper maintenance.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Cleaning of upholstery protects fabric and maintains sofa quality.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Cleaning of upholsteries removes embedded dust and improves seating comfort.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Cleaned a upholstery restored sofa appearance and removed stains effectively.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Cleaned a upholsteries ensured fabric cleanliness and improved comfort.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Cleaned upholstery eliminated dirt and maintained proper sofa hygiene.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Cleaned upholsteries removed stubborn stains and prolonged sofa lifespan.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),

      # ----------- Bed Maintenance -----------
    #frame tightening
    ("Frame tightening secures bed joints and ensures structural stability.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Bed frame tightening prevents wobbling and maintains bed durability.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Tightening frame reinforces loose joints and strengthens the bed structure.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Tightening frames secures all connections and improves bed stability.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Tightening of frame ensures proper support and prevents creaking.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Tightening of frames strengthens bed joints and maintains comfort.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Tightening bed frame stabilizes the bed and prevents structural issues.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Tightening bed frames ensures bed safety and prolongs furniture lifespan.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Tightened a frame secured all joints and improved bed stability.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Tightened a frames reinforced connections and enhanced bed durability.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Tightened a bed frame fixed loose joints and ensured safety.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Tightened bed frames stabilized structure and improved comfort.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    #slat replacement
    ("Slat replacement restores bed support and prevents sagging.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Slat replacements ensure even weight distribution and bed stability.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Bed slat replacement fixes broken slats and strengthens the bed structure.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Bed slat replacements restore proper support and improve bed comfort.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Replacing slat reinforces bed structure and prevents further damage.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replacing slats maintains proper bed support and enhances comfort.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replacing bed slat restores sagging areas and strengthens bed frame.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Replacing bed slats ensures stability and prolongs bed lifespan.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Replaced a slat fixed broken areas and restored bed support.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Replaced a slats strengthened weak points and improved bed comfort.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Replaced a bed slat repaired sagging and ensured proper support.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Replaced bed slats restored bed stability and enhanced overall comfort.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    #mattress rotation
    ("Mattress rotation ensures even wear and prolongs mattress lifespan.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Mattress rotations prevent sagging and maintain bed comfort.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Bed mattress rotation improves support and extends bed life.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Bed mattress rotations distribute weight evenly and prevent damage.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Rotation mattress maintains comfort and ensures even mattress wear.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Rotation mattresses prevents uneven sagging and extends bed life.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Rotation of bed mattress redistributes pressure points and improves support.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Rotation of bed mattresses prolongs mattress life and maintains comfort.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Rotated a mattress ensured even wear and restored comfort.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Rotated a mattresses corrected sagging and improved bed support.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Rotated a bed mattress redistributed weight and enhanced support.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Rotated bed mattresses maintained comfort and prolonged mattress life.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    #headboard repair
    ("Headboard repair fixes loose panels and restores bed stability.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Headboard repairs reinforce weak joints and improve bed durability.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Bed headboard repair secures the headboard and prevents wobbling.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Bed headboard repairs maintain structure and extend bed lifespan.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repairing headboard restores alignment and enhances support.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repairing headboards fixes loose components and strengthens bed.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repairing bed headboard secures the structure and prevents damage.", 
     {"entities": [(0, 23, "SKILLS"), (27, 52, "SERVICE"), (56, 81, "SPECIALIZATION")]}),
    ("Repairing bed headboards restores stability and prolongs bed life.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Repaired a headboard fixed loose joints and reinforced the bed.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repaired a headboards strengthened weak panels and improved support.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Repaired a bed headboard corrected misalignment and secured structure.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Repaired bed headboards restored stability and enhanced bed comfort.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),

      # ----------- Cabinet Maintenance -----------
    #lock replacement
    ("Lock replacement secures cabinet doors and prevents unauthorized access.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Lock replacements ensure cabinet safety and improve door functionality.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Cabinet lock replacement restores cabinet security and prevents tampering.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Cabinet lock replacements maintain safety and prolong cabinet lifespan.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Replacing lock secures doors and ensures smooth operation.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Replacing locks strengthens cabinet security and prevents damage.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replacing cabinet lock fixes faulty latches and restores security.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Replacing cabinet locks improves functionality and prevents break-ins.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Replaced a lock secured cabinet doors and enhanced safety.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Replaced a locks restored security and improved cabinet usage.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Replaced a cabinet lock repaired faulty latches and ensured safety.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Replaced a cabinet locks enhanced door security and prevented tampering.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    #handle replacement
    ("Handle replacement improves cabinet usability and secures doors.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Handle replacements maintain cabinet functionality and prevent damage.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Cabinet handle replacement fixes loose handles and ensures smooth operation.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Cabinet handle replacements restore cabinet usability and improve safety.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Replacing handle secures doors and improves cabinet performance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replacing handles strengthens cabinet doors and enhances functionality.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replacing cabinet handle fixes faulty latches and improves operation.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Replacing cabinet handles restores functionality and prevents break-ins.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Replaced a handle repaired loose components and secured the cabinet.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Replaced a handles restored door functionality and improved cabinet usage.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Replaced a cabinet handle corrected alignment and enhanced cabinet security.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Replaced a cabinet handles maintained door integrity and prevented damage.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    #cabinet refacing
    ("Cabinet refacing updates the appearance and extends cabinet lifespan.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Cabinet refacings refresh cabinet surfaces and improve functionality.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Refacing cabinet enhances aesthetics and prolongs cabinet usage.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Refacing cabinets renews surfaces and strengthens overall cabinet structure.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Refacing of cabinet improves cabinet look and restores functionality.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Refacing of cabinets updates worn surfaces and prevents further damage.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Refaced a cabinet renewed surface and enhanced cabinet durability.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Refaced a cabinets restored worn surfaces and improved cabinet safety.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Refaced cabinet refreshed appearance and prolonged cabinet lifespan.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Refaced cabinets enhanced surface quality and restored cabinet aesthetics.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    #cabinet repair
    ("Hinge replacement ensures cabinet doors swing smoothly and safely.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Hinge replacements maintain door alignment and prevent wear over time.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Cabinet hinge replacement fixes loose hinges and restores door functionality.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Cabinet hinge replacements secure doors and improve cabinet durability.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Replacing hinge corrects door alignment and enhances cabinet performance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replacing hinges strengthens cabinet doors and ensures smooth operation.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replacing cabinet hinge fixes squeaky doors and restores proper movement.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Replacing cabinet hinges maintains door stability and prevents misalignment.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Replaced a hinge repaired faulty connections and ensured smooth swing.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Replaced a hinges restored door function and improved cabinet usage.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Replaced a cabinet hinge fixed misaligned doors and enhanced durability.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Replaced a cabinet hinges corrected alignment and ensured proper operation.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    #hinge replacement 
    ("Hinge replacement ensures smooth door operation and prevents damage.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Hinge replacements maintain proper door alignment and functionality.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Cabinet hinge replacement fixes loose doors and improves cabinet safety.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Cabinet hinge replacements secure doors and enhance cabinet durability.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Replacing hinge corrects misalignment and ensures smooth door operation.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Replacing hinges strengthens doors and maintains cabinet functionality.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Replacing cabinet hinge fixes squeaky doors and restores smooth movement.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Replacing cabinet hinges ensures door stability and prevents misalignment.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Replaced a hinge repaired faulty doors and restored proper swing.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Replaced a hinges fixed misaligned doors and enhanced cabinet safety.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Replaced a cabinet hinge corrected loose doors and restored alignment.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Replaced a cabinet hinges repaired faulty doors and maintained cabinet durability.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),

      # ----------- Door Maintenance ----------
    #door alignment
    ("Door alignment ensures smooth door operation and prevents sticking.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Door alignments maintain proper door function and improve cabinet usage.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Aligning door corrects misalignment and enhances door performance.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Aligning doors maintains cabinet door alignment and ensures smooth operation.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Aligning of door fixes sagging doors and restores proper swing.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Aligning of doors corrects crooked doors and prevents wear over time.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Aligned a door fixed misaligned doors and restored smooth operation.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Aligned a doors repaired crooked doors and ensured proper alignment.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Aligned door corrected sagging doors and enhanced cabinet performance.", 
     {"entities": [(0, 11, "SKILLS"), (15, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Aligned doors restored proper function and improved door stability.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    #door repair
    ("Door repair fixes broken doors and restores proper function.", 
     {"entities": [(0, 11, "SKILLS"), (15, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Door repairs maintain door integrity and prevent further damage.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Repairing door restores alignment and ensures smooth operation.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Repairing doors corrects misalignment and strengthens cabinet doors.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Repairing of door fixes squeaky hinges and restores proper swing.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repairing of doors corrects warped panels and enhances door durability.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repaired a door fixed broken panels and restored proper function.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Repaired a doors corrected misaligned hinges and strengthened cabinet doors.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Repaired door restored proper swing and fixed sagging panels.", 
     {"entities": [(0, 11, "SKILLS"), (15, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Repaired doors fixed warped panels and ensured smooth operation.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    #weather stripping intallation
    ("Weather stripping installation prevents drafts and improves door insulation.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Weather stripping installations maintain proper sealing and enhance energy efficiency.", 
     {"entities": [(0, 31, "SKILLS"), (35, 60, "SERVICE"), (64, 89, "SPECIALIZATION")]}),
    ("Installing weather stripping seals gaps around doors and reduces energy loss.", 
     {"entities": [(0, 28, "SKILLS"), (32, 57, "SERVICE"), (61, 86, "SPECIALIZATION")]}),
    ("Installing weather strippings ensures tight sealing and prevents drafts.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Installing of weather stripping corrects leaks and improves door efficiency.", 
     {"entities": [(0, 31, "SKILLS"), (35, 60, "SERVICE"), (64, 89, "SPECIALIZATION")]}),
    ("Installing of weather strippings strengthens door seals and enhances insulation.", 
     {"entities": [(0, 32, "SKILLS"), (36, 61, "SERVICE"), (65, 90, "SPECIALIZATION")]}),
    ("Installed a weather stripping repaired gaps and improved door insulation.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),
    ("Installed a weather strippings fixed leaks and ensured proper sealing.", 
     {"entities": [(0, 31, "SKILLS"), (35, 60, "SERVICE"), (64, 89, "SPECIALIZATION")]}),
    ("Installed weather stripping corrected gaps and enhanced door energy efficiency.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Installed weather strippings reinforced door seals and reduced energy loss.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),
    #roller repair
    ("Roller repair fixes stuck rollers and restores smooth sliding of doors.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Roller repairs maintain proper roller function and improve door movement.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Roller track repair restores proper track alignment and smooth sliding.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Roller track repairs prevent sticking and enhance door operation.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repairing roller ensures smooth movement and fixes door jams.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repairing rollers corrects worn rollers and restores proper sliding.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repairing roller track aligns tracks and ensures smooth door operation.", 
     {"entities": [(0, 24, "SKILLS"), (28, 53, "SERVICE"), (57, 82, "SPECIALIZATION")]}),
    ("Repairing roller tracks fixes misaligned tracks and enhances sliding.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Repairing of roller replaces worn rollers and improves functionality.", 
     {"entities": [(0, 25, "SKILLS"), (29, 54, "SERVICE"), (58, 83, "SPECIALIZATION")]}),
    ("Repairing of rollers restores smooth sliding and prevents door jams.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Repairing of roller track corrects misaligned tracks and enhances movement.", 
     {"entities": [(0, 29, "SKILLS"), (33, 58, "SERVICE"), (62, 87, "SPECIALIZATION")]}),
    ("Repairing of roller tracks fixes worn tracks and restores door function.", 
     {"entities": [(0, 30, "SKILLS"), (34, 59, "SERVICE"), (63, 88, "SPECIALIZATION")]}),
    ("Repaired a roller fixed stuck rollers and restored smooth sliding.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Repaired a rollers replaced worn rollers and improved door operation.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repaired a roller track fixed misaligned tracks and restored sliding.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repaired a roller tracks aligned tracks and ensured smooth movement.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Repaired roller corrected worn rollers and enhanced door function.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Repaired rollers replaced damaged rollers and improved sliding operation.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Repaired roller track fixed bent tracks and restored proper alignment.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repaired roller tracks corrected misaligned tracks and ensured smooth operation.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    #scratch repair
    ("Scratch repair removes surface scratches and restores door finish.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Scratch repairs maintain door appearance and prevent further damage.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Repairing scratch corrects minor door marks and smooths surfaces.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repairing scratches removes dents and improves door aesthetics.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repairing of scratch fixes surface imperfections and restores finish.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Repairing of scratches restores door surface and prevents further wear.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Repaired a scratch removed visible marks and restored smooth surface.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repaired a scratches fixed surface imperfections and improved door finish.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Repaired scratch corrected minor scratches and enhanced door appearance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Repaired scratches restored door surface and removed dents.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    #dent repair
    ("Dent repair fixes minor door dents and restores the smooth surface.", 
     {"entities": [(0, 11, "SKILLS"), (15, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Dent repairs maintain door integrity and remove unsightly dents.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Repairing dent corrects small dents and improves door appearance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Repairing dents removes surface dents and restores proper finish.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repairing of dent fixes door imperfections and smooths out dents.", 
     {"entities": [(0, 19, "SKILLS"), (23, 48, "SERVICE"), (52, 77, "SPECIALIZATION")]}),
    ("Repairing of dents restores door surface and removes small dents.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Repaired a dent corrected minor dents and improved door finish.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Repaired a dents removed dents and restored smooth door surface.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Repaired dent fixed visible dents and enhanced overall door appearance.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Repaired dents restored door surface and eliminated minor dents.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    #automatic door mechanism
    ("Automatic door mechanism ensures smooth operation of sliding doors.", 
     {"entities": [(0, 26, "SKILLS"), (30, 55, "SERVICE"), (59, 84, "SPECIALIZATION")]}),
    ("Automatic door mechanisms enhance door functionality and user safety.", 
     {"entities": [(0, 27, "SKILLS"), (31, 56, "SERVICE"), (60, 85, "SPECIALIZATION")]}),
    ("Installing automatic door mechanism improves entrance convenience and reliability.", 
     {"entities": [(0, 33, "SKILLS"), (37, 62, "SERVICE"), (66, 91, "SPECIALIZATION")]}),
    ("Installing automatic door mechanisms upgrades doors with modern functionality.", 
     {"entities": [(0, 34, "SKILLS"), (38, 63, "SERVICE"), (67, 92, "SPECIALIZATION")]}),
    ("Installing of automatic door mechanism provides efficient entry and exit.", 
     {"entities": [(0, 36, "SKILLS"), (40, 65, "SERVICE"), (69, 94, "SPECIALIZATION")]}),
    ("Installing of automatic door mechanisms allows doors to operate smoothly.", 
     {"entities": [(0, 37, "SKILLS"), (41, 66, "SERVICE"), (70, 95, "SPECIALIZATION")]}),
    ("Installed a automatic door mechanism enhanced door convenience and security.", 
     {"entities": [(0, 35, "SKILLS"), (39, 64, "SERVICE"), (68, 93, "SPECIALIZATION")]}),
    ("Installed a automatic door mechanisms upgraded doors with automated functionality.", 
     {"entities": [(0, 36, "SKILLS"), (40, 65, "SERVICE"), (69, 94, "SPECIALIZATION")]}),
    ("Installed automatic door mechanism improved entry system and overall door operation.", 
     {"entities": [(0, 34, "SKILLS"), (38, 63, "SERVICE"), (67, 92, "SPECIALIZATION")]}),
    ("Installed automatic door mechanisms allowed smooth operation and increased safety of doors.", 
     {"entities": [(0, 35, "SKILLS"), (39, 64, "SERVICE"), (68, 93, "SPECIALIZATION")]}),
    #hinge adjustment
    ("Hinge adjustment ensures proper door alignment and smooth operation.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Hinge adjustments correct misaligned doors and prevent further wear.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Adjusting hinge fixes minor misalignment and improves door performance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Adjusting hinges corrects alignment issues and ensures smooth door operation.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Adjusting of hinge restores proper door swing and prevents sticking.", 
     {"entities": [(0, 20, "SKILLS"), (24, 49, "SERVICE"), (53, 78, "SPECIALIZATION")]}),
    ("Adjusting of hinges improves door movement and prevents squeaking.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Adjusted a hinge corrected door alignment and restored smooth operation.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Adjusted a hinges fixed door misalignment and improved performance.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Adjusted hinge restored proper door swing and prevented sticking.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Adjusted hinges corrected alignment issues and enhanced door functionality.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),

      # ----------- General Cleaning ----------- 
    #sweeping floor
    ("Sweeping floor keeps the room tidy and removes dirt from surfaces.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Sweeping floors removes dust and maintains cleanliness in the home.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Sweeping of floor ensures all corners are clean and dust-free.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Sweeping of floors eliminates debris and keeps surfaces spotless.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Floor sweeping maintains hygiene and removes scattered dirt.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Floor sweepings clean all areas thoroughly and improve appearance.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Swept a floor removed dust and dirt, leaving it clean and tidy.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Swept a floors cleaned the living room and maintained hygiene.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Swept floor tidied all rooms and removed debris from corners.", 
     {"entities": [(0, 11, "SKILLS"), (15, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Swept floors ensured cleanliness and maintained a neat environment.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    #mopping floor
    ("Mopping floor removes dirt and maintains a clean home environment.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Mopping floors ensures all surfaces are spotless and hygienic.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Mopping of floors keeps the area tidy and free from stains.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Floor mopping effectively cleans and sanitizes all walking areas.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Floor moppings maintain hygiene and improve the appearance of rooms.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Mopped a floor removed dust and stains, leaving the room spotless.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Mopped a floors cleaned the entire kitchen and maintained hygiene.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Mopped floor ensured all areas were clean and free from grime.", 
     {"entities": [(0, 11, "SKILLS"), (15, 40, "SERVICE"), (44, 69, "SPECIALIZATION")]}),
    ("Mopped floors tidied the hallway and removed sticky residues.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    #surface wiping
    ("Surface wiping removes dust and grime from all furniture surfaces.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Surface wipings ensure all counters and tables remain spotless.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Wiping surface cleans the table thoroughly and maintains hygiene.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Wiping surfaces removes dust from shelves and cabinets.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Wiping of surface ensures cleanliness and prevents stains.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Wiping of surfaces sanitizes all areas and removes residues.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Wiped a surface removed sticky residues and dust from the table.", 
     {"entities": [(0, 13, "SKILLS"), (17, 42, "SERVICE"), (46, 71, "SPECIALIZATION")]}),
    ("Wiped a surfaces cleaned the counters thoroughly.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Wiped surface ensured all surfaces were free of dust and dirt.", 
     {"entities": [(0, 12, "SKILLS"), (16, 41, "SERVICE"), (45, 70, "SPECIALIZATION")]}),
    ("Wiped surfaces maintained hygiene and cleanliness in the office.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    #vacuuming carpet
    ("Vacuuming carpet removes dirt and dust from all floor areas.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Vacuuming carpets ensures all rugs are clean and dust-free.", 
     {"entities": [(0, 17, "SKILLS"), (21, 46, "SERVICE"), (50, 75, "SPECIALIZATION")]}),
    ("Vacuuming of carpet effectively removes pet hair and debris.", 
     {"entities": [(0, 21, "SKILLS"), (25, 50, "SERVICE"), (54, 79, "SPECIALIZATION")]}),
    ("Vacuuming of carpets maintains cleanliness and hygiene in rooms.", 
     {"entities": [(0, 22, "SKILLS"), (26, 51, "SERVICE"), (55, 80, "SPECIALIZATION")]}),
    ("Carpet vacuuming keeps all areas spotless and free from dust.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Carpet vacuumings remove dirt and maintain a tidy environment.", 
     {"entities": [(0, 18, "SKILLS"), (22, 47, "SERVICE"), (51, 76, "SPECIALIZATION")]}),
    ("Vacuumed a carpet removed dust and debris from the living room.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    ("Vacuumed a carpets cleaned all rugs thoroughly.", 
     {"entities": [(0, 16, "SKILLS"), (20, 45, "SERVICE"), (49, 74, "SPECIALIZATION")]}),
    ("Vacuumed carpet ensured all areas were free from dust and dirt.", 
     {"entities": [(0, 14, "SKILLS"), (18, 43, "SERVICE"), (47, 72, "SPECIALIZATION")]}),
    ("Vacuumed carpets maintained hygiene and cleanliness in the home.", 
     {"entities": [(0, 15, "SKILLS"), (19, 44, "SERVICE"), (48, 73, "SPECIALIZATION")]}),
    #organizing
    ("Organizing the kitchen shelves makes it easier to find utensils.", 
     {"entities": [(0, 10, "SKILLS"), (14, 32, "SERVICE"), (36, 61, "SPECIALIZATION")]}),
    ("Organizing of the living room items improves room aesthetics.", 
     {"entities": [(0, 15, "SKILLS"), (19, 37, "SERVICE"), (41, 66, "SPECIALIZATION")]}),
    ("Organizing closets ensures all clothes are in proper order.", 
     {"entities": [(0, 10, "SKILLS"), (14, 32, "SERVICE"), (36, 61, "SPECIALIZATION")]}),
    ("Organizing of office supplies reduces clutter and improves efficiency.", 
     {"entities": [(0, 15, "SKILLS"), (19, 37, "SERVICE"), (41, 66, "SPECIALIZATION")]}),
    ("Organized a bedroom made it easier to locate personal items.", 
     {"entities": [(0, 11, "SKILLS"), (15, 33, "SERVICE"), (37, 62, "SPECIALIZATION")]}),
    ("Organized a kitchen countertop cleared space for cooking.", 
     {"entities": [(0, 11, "SKILLS"), (15, 33, "SERVICE"), (37, 62, "SPECIALIZATION")]}),
    ("Organized the wardrobe sorted all clothes by color and type.", 
     {"entities": [(0, 10, "SKILLS"), (14, 32, "SERVICE"), (36, 61, "SPECIALIZATION")]}),
    ("Organized office drawers improved accessibility and tidiness.", 
     {"entities": [(0, 10, "SKILLS"), (14, 32, "SERVICE"), (36, 61, "SPECIALIZATION")]}),
    #decluttering
     ("Decluttering the study desk removes unnecessary items and improves focus.", 
     {"entities": [(0, 11, "SKILLS"), (15, 33, "SERVICE"), (37, 62, "SPECIALIZATION")]}),
    ("Decluttering of the living room area enhances space and tidiness.", 
     {"entities": [(0, 16, "SKILLS"), (20, 38, "SERVICE"), (42, 67, "SPECIALIZATION")]}),
    ("Decluttering the pantry organizes all items for easy access.", 
     {"entities": [(0, 11, "SKILLS"), (15, 33, "SERVICE"), (37, 62, "SPECIALIZATION")]}),
    ("Decluttering of office cabinets improves work efficiency and space.", 
     {"entities": [(0, 16, "SKILLS"), (20, 38, "SERVICE"), (42, 67, "SPECIALIZATION")]}),
    ("Decluttered a bedroom removed unused furniture and items.", 
     {"entities": [(0, 14, "SKILLS"), (18, 36, "SERVICE"), (40, 65, "SPECIALIZATION")]}),
    ("Decluttered a kitchen cleared shelves and counters of unnecessary items.", 
     {"entities": [(0, 14, "SKILLS"), (18, 36, "SERVICE"), (40, 65, "SPECIALIZATION")]}),
    ("Decluttered the wardrobe sorted and removed unused clothes.", 
     {"entities": [(0, 12, "SKILLS"), (16, 34, "SERVICE"), (38, 63, "SPECIALIZATION")]}),
    ("Decluttered office drawers organized all items and removed trash.", 
     {"entities": [(0, 12, "SKILLS"), (16, 34, "SERVICE"), (38, 63, "SPECIALIZATION")]}),

      # ----------- Deep Cleaning -----------
    #tile scrubbing
    ("Tile scrubbing removes dirt and grime from bathroom floors.", 
     {"entities": [(0, 13, "SKILLS"), (17, 34, "SERVICE"), (38, 61, "SPECIALIZATION")]}),
    ("Tile scrubbings ensure all tiles remain spotless and shiny.", 
     {"entities": [(0, 15, "SKILLS"), (19, 36, "SERVICE"), (40, 63, "SPECIALIZATION")]}),
    ("Scrubbing tile eliminates stubborn stains and buildup.", 
     {"entities": [(0, 13, "SKILLS"), (17, 34, "SERVICE"), (38, 61, "SPECIALIZATION")]}),
    ("Scrubbing tiles keeps floors clean and hygienic.", 
     {"entities": [(0, 14, "SKILLS"), (18, 35, "SERVICE"), (39, 62, "SPECIALIZATION")]}),
    ("Scrubbing of tile maintains the longevity of bathroom surfaces.", 
     {"entities": [(0, 16, "SKILLS"), (20, 37, "SERVICE"), (41, 64, "SPECIALIZATION")]}),
    ("Scrubbing of tiles ensures grout lines remain clean.", 
     {"entities": [(0, 17, "SKILLS"), (21, 38, "SERVICE"), (42, 65, "SPECIALIZATION")]}),
    ("Scrubbed a tile removed all stains and soap scum effectively.", 
     {"entities": [(0, 14, "SKILLS"), (18, 35, "SERVICE"), (39, 62, "SPECIALIZATION")]}),
    ("Scrubbed a tiles cleaned the floor thoroughly.", 
     {"entities": [(0, 15, "SKILLS"), (19, 36, "SERVICE"), (40, 63, "SPECIALIZATION")]}),
    ("Scrubbed tile polished surfaces and removed grime.", 
     {"entities": [(0, 12, "SKILLS"), (16, 33, "SERVICE"), (37, 60, "SPECIALIZATION")]}),
    ("Scrubbed tiles restored shine and cleanliness to the floors.", 
     {"entities": [(0, 13, "SKILLS"), (17, 34, "SERVICE"), (38, 61, "SPECIALIZATION")]}),
    #steam clearning
    ("Steam cleaning removes deep-seated dirt from carpets and upholstery.", 
     {"entities": [(0, 14, "SKILLS"), (18, 33, "SERVICE"), (37, 56, "SPECIALIZATION")]}),
    ("Cleaning with steam sanitizes floors and furniture effectively.", 
     {"entities": [(0, 18, "SKILLS"), (22, 37, "SERVICE"), (41, 60, "SPECIALIZATION")]}),
    ("Cleaning by steam disinfects surfaces without chemicals.", 
     {"entities": [(0, 17, "SKILLS"), (21, 36, "SERVICE"), (40, 59, "SPECIALIZATION")]}),
    ("Steam cleaned a carpet removed stubborn stains easily.", 
     {"entities": [(0, 14, "SKILLS"), (18, 33, "SERVICE"), (37, 56, "SPECIALIZATION")]}),
    ("Steam cleaned sofas sanitized them thoroughly.", 
     {"entities": [(0, 13, "SKILLS"), (17, 32, "SERVICE"), (36, 55, "SPECIALIZATION")]}),
    #stain removal
    ("Stain removal eliminates tough spots from carpets and fabrics.", 
     {"entities": [(0, 13, "SKILLS"), (17, 34, "SERVICE"), (38, 57, "SPECIALIZATION")]}),
    ("Stain removals are essential for keeping upholstery clean and fresh.", 
     {"entities": [(0, 15, "SKILLS"), (19, 36, "SERVICE"), (40, 59, "SPECIALIZATION")]}),
    ("Removing stain from the couch improves its appearance and hygiene.", 
     {"entities": [(0, 14, "SKILLS"), (18, 35, "SERVICE"), (39, 58, "SPECIALIZATION")]}),
    ("Removing stains from the carpet enhances overall cleanliness.", 
     {"entities": [(0, 16, "SKILLS"), (20, 37, "SERVICE"), (41, 60, "SPECIALIZATION")]}),
    ("Removing of stain on the sofa prevents permanent marks.", 
     {"entities": [(0, 17, "SKILLS"), (21, 38, "SERVICE"), (42, 61, "SPECIALIZATION")]}),
    ("Removing of stains from upholstery maintains fabric quality.", 
     {"entities": [(0, 18, "SKILLS"), (22, 39, "SERVICE"), (43, 62, "SPECIALIZATION")]}),
    ("Removed a stain from the carpet using a professional cleaning method.", 
     {"entities": [(0, 14, "SKILLS"), (18, 35, "SERVICE"), (39, 58, "SPECIALIZATION")]}),
    ("Removed a stains from the sofa restored its original look.", 
     {"entities": [(0, 15, "SKILLS"), (19, 36, "SERVICE"), (40, 59, "SPECIALIZATION")]}),
    ("Removed stain from the dining chair quickly and effectively.", 
     {"entities": [(0, 12, "SKILLS"), (16, 33, "SERVICE"), (37, 56, "SPECIALIZATION")]}),
    ("Removed stains from curtains enhanced the room's overall cleanliness.", 
     {"entities": [(0, 13, "SKILLS"), (17, 34, "SERVICE"), (38, 57, "SPECIALIZATION")]}),
    #upholstery deep cleaning
    ("Upholstery deep cleaning removes dirt and allergens from sofas.", 
     {"entities": [(0, 23, "SKILLS"), (27, 48, "SERVICE"), (52, 72, "SPECIALIZATION")]}),
    ("Upholstery deep cleanings help maintain furniture hygiene and appearance.", 
     {"entities": [(0, 25, "SKILLS"), (29, 50, "SERVICE"), (54, 74, "SPECIALIZATION")]}),
    ("Deep cleaning upholstery restores the look and feel of old furniture.", 
     {"entities": [(0, 21, "SKILLS"), (25, 46, "SERVICE"), (50, 70, "SPECIALIZATION")]}),
    ("Deep cleaning upholsteries removes stains and embedded dust effectively.", 
     {"entities": [(0, 22, "SKILLS"), (26, 47, "SERVICE"), (51, 71, "SPECIALIZATION")]}),
    ("Deep cleaning of upholstery protects the fabric and extends its life.", 
     {"entities": [(0, 26, "SKILLS"), (30, 51, "SERVICE"), (55, 75, "SPECIALIZATION")]}),
    ("Deep cleaning of upholsteries ensures the sofa remains fresh and clean.", 
     {"entities": [(0, 27, "SKILLS"), (31, 52, "SERVICE"), (56, 76, "SPECIALIZATION")]}),
    ("Deep cleaned a upholstery restored its original softness and shine.", 
     {"entities": [(0, 22, "SKILLS"), (26, 47, "SERVICE"), (51, 71, "SPECIALIZATION")]}),
    ("Deep cleaned a upholsteries sanitized the furniture thoroughly.", 
     {"entities": [(0, 23, "SKILLS"), (27, 48, "SERVICE"), (52, 72, "SPECIALIZATION")]}),
    ("Deep cleaned upholstery removed stubborn stains and odors.", 
     {"entities": [(0, 20, "SKILLS"), (24, 45, "SERVICE"), (49, 69, "SPECIALIZATION")]}),
    ("Deep cleaned upholsteries enhanced the comfort and appearance of the sofa.", 
     {"entities": [(0, 21, "SKILLS"), (25, 46, "SERVICE"), (50, 70, "SPECIALIZATION")]}),
    #mattress sanitizing
    ("Mattress sanitizing removes dust mites and allergens effectively.", 
     {"entities": [(0, 19, "SKILLS"), (23, 37, "SERVICE"), (41, 60, "SPECIALIZATION")]}),
    ("Mattress sanitizings are essential for maintaining healthy sleeping surfaces.", 
     {"entities": [(0, 21, "SKILLS"), (25, 39, "SERVICE"), (43, 62, "SPECIALIZATION")]}),
    ("Sanitizing mattress prevents buildup of germs and bacteria.", 
     {"entities": [(0, 18, "SKILLS"), (22, 36, "SERVICE"), (40, 59, "SPECIALIZATION")]}),
    ("Sanitizing mattresses improves hygiene and extends mattress lifespan.", 
     {"entities": [(0, 20, "SKILLS"), (24, 38, "SERVICE"), (42, 61, "SPECIALIZATION")]}),
    ("Sanitizing of mattress ensures a clean and healthy sleeping environment.", 
     {"entities": [(0, 22, "SKILLS"), (26, 40, "SERVICE"), (44, 63, "SPECIALIZATION")]}),
    ("Sanitizing of mattresses protects the bed from dust and microbes.", 
     {"entities": [(0, 23, "SKILLS"), (27, 41, "SERVICE"), (45, 64, "SPECIALIZATION")]}),
    ("Sanitized a mattress removed dust and stains thoroughly.", 
     {"entities": [(0, 18, "SKILLS"), (22, 36, "SERVICE"), (40, 59, "SPECIALIZATION")]}),
    ("Sanitized a mattresses ensured complete hygiene of the sleeping area.", 
     {"entities": [(0, 20, "SKILLS"), (24, 38, "SERVICE"), (42, 61, "SPECIALIZATION")]}),
    ("Sanitized mattress eliminated allergens effectively.", 
     {"entities": [(0, 16, "SKILLS"), (20, 34, "SERVICE"), (38, 57, "SPECIALIZATION")]}),
    ("Sanitized mattresses improved overall bed hygiene.", 
     {"entities": [(0, 18, "SKILLS"), (22, 36, "SERVICE"), (40, 59, "SPECIALIZATION")]}),
    #vacuuming carpet
    ("Vacuuming carpet removes dust and debris efficiently from floors.", 
     {"entities": [(0, 16, "SKILLS"), (20, 37, "SERVICE"), (41, 57, "SPECIALIZATION")]}),
    ("Vacuuming carpets helps maintain a clean and hygienic home.", 
     {"entities": [(0, 18, "SKILLS"), (22, 39, "SERVICE"), (43, 59, "SPECIALIZATION")]}),
    ("Vacuuming of carpet ensures the carpet fibers remain fresh.", 
     {"entities": [(0, 21, "SKILLS"), (25, 42, "SERVICE"), (46, 62, "SPECIALIZATION")]}),
    ("Vacuuming of carpets is essential for keeping dust under control.", 
     {"entities": [(0, 22, "SKILLS"), (26, 43, "SERVICE"), (47, 63, "SPECIALIZATION")]}),
    ("Carpet vacuuming removes pet hair and small debris effectively.", 
     {"entities": [(0, 15, "SKILLS"), (19, 36, "SERVICE"), (40, 56, "SPECIALIZATION")]}),
    ("Carpet vacuumings improve indoor air quality and hygiene.", 
     {"entities": [(0, 17, "SKILLS"), (21, 38, "SERVICE"), (42, 58, "SPECIALIZATION")]}),
    ("Vacuumed a carpet removed all dust and small particles thoroughly.", 
     {"entities": [(0, 16, "SKILLS"), (20, 37, "SERVICE"), (41, 57, "SPECIALIZATION")]}),
    ("Vacuumed a carpets helped in keeping the home clean and tidy.", 
     {"entities": [(0, 18, "SKILLS"), (22, 39, "SERVICE"), (43, 59, "SPECIALIZATION")]}),
    ("Vacuumed carpet efficiently removed embedded dirt and debris.", 
     {"entities": [(0, 14, "SKILLS"), (18, 35, "SERVICE"), (39, 55, "SPECIALIZATION")]}),
    ("Vacuumed carpets thoroughly cleaned the floor and improved hygiene.", 
     {"entities": [(0, 16, "SKILLS"), (20, 37, "SERVICE"), (41, 57, "SPECIALIZATION")]}),

      # ----------- Laundry -----------
    #clothes sorting
    ("Clothes sorting helps separate whites and colors before washing.", 
     {"entities": [(0, 15, "SKILLS"), (19, 34, "SERVICE"), (38, 44, "SPECIALIZATION")]}),
    ("Clothes sortings are necessary to prevent color bleeding in laundry.", 
     {"entities": [(0, 16, "SKILLS"), (20, 35, "SERVICE"), (39, 45, "SPECIALIZATION")]}),
    ("Sorting cloth ensures garments are cleaned appropriately.", 
     {"entities": [(0, 11, "SKILLS"), (15, 30, "SERVICE"), (34, 40, "SPECIALIZATION")]}),
    ("Sorting clothes properly reduces damage during washing cycles.", 
     {"entities": [(0, 14, "SKILLS"), (18, 33, "SERVICE"), (37, 43, "SPECIALIZATION")]}),
    ("Sorting of clothes is essential for efficient laundry management.", 
     {"entities": [(0, 17, "SKILLS"), (21, 36, "SERVICE"), (40, 46, "SPECIALIZATION")]}),
    ("Sorted cloth before washing prevents color transfer.", 
     {"entities": [(0, 11, "SKILLS"), (15, 30, "SERVICE"), (34, 40, "SPECIALIZATION")]}),
    ("Sorted a cloth separated delicate items from heavy fabrics.", 
     {"entities": [(0, 13, "SKILLS"), (17, 32, "SERVICE"), (36, 42, "SPECIALIZATION")]}),
    ("Sorted a clothes organized laundry before starting the wash.", 
     {"entities": [(0, 15, "SKILLS"), (19, 34, "SERVICE"), (38, 44, "SPECIALIZATION")]}),
    ("Sorted cloth arranged garments by type and color for washing.", 
     {"entities": [(0, 10, "SKILLS"), (14, 29, "SERVICE"), (33, 39, "SPECIALIZATION")]}),
    ("Sorted clothes ensured proper washing procedures for each fabric.", 
     {"entities": [(0, 13, "SKILLS"), (17, 32, "SERVICE"), (36, 42, "SPECIALIZATION")]}),
    #hand washing
    ("Hand washing is necessary for delicate fabrics to prevent damage.", 
     {"entities": [(0, 12, "SKILLS"), (16, 23, "SERVICE"), (27, 33, "SPECIALIZATION")]}),
    ("Washing by hand ensures that fragile clothes are cleaned gently.", 
     {"entities": [(0, 15, "SKILLS"), (19, 26, "SERVICE"), (30, 36, "SPECIALIZATION")]}),
    ("Washing of clothes by hand helps maintain fabric quality.", 
     {"entities": [(0, 23, "SKILLS"), (27, 34, "SERVICE"), (38, 44, "SPECIALIZATION")]}),
    ("Hand washed delicate shirts to prevent them from shrinking.", 
     {"entities": [(0, 10, "SKILLS"), (14, 21, "SERVICE"), (25, 31, "SPECIALIZATION")]}),
    ("Hand washed a sweater carefully to avoid damage.", 
     {"entities": [(0, 12, "SKILLS"), (16, 23, "SERVICE"), (27, 33, "SPECIALIZATION")]}),
    ("Hand washed clothes properly to remove stains effectively.", 
     {"entities": [(0, 13, "SKILLS"), (17, 24, "SERVICE"), (28, 34, "SPECIALIZATION")]}),
    #hand washing delicates
    ("Hand washing delicates requires extra care to prevent fabric damage.", 
     {"entities": [(0, 22, "SKILLS"), (26, 33, "SERVICE"), (37, 43, "SPECIALIZATION")]}),
    ("Hand washing delicate items helps maintain their shape and softness.", 
     {"entities": [(0, 21, "SKILLS"), (25, 32, "SERVICE"), (36, 42, "SPECIALIZATION")]}),
    ("Washing delicates by hand is essential for silk and wool garments.", 
     {"entities": [(0, 21, "SKILLS"), (25, 32, "SERVICE"), (36, 42, "SPECIALIZATION")]}),
    ("Washing a delicate by hand ensures that fragile fabrics stay intact.", 
     {"entities": [(0, 23, "SKILLS"), (27, 34, "SERVICE"), (38, 44, "SPECIALIZATION")]}),
    ("Hand washed a delicate sweater carefully to avoid damage.", 
     {"entities": [(0, 23, "SKILLS"), (27, 34, "SERVICE"), (38, 44, "SPECIALIZATION")]}),
    ("Hand washed delicates like silk scarves and lace tops.", 
     {"entities": [(0, 19, "SKILLS"), (23, 30, "SERVICE"), (34, 40, "SPECIALIZATION")]}),
    ("Hand washed delicate fabrics separately to prevent color bleeding.", 
     {"entities": [(0, 21, "SKILLS"), (25, 32, "SERVICE"), (36, 42, "SPECIALIZATION")]}),
    #ironing
    ("Ironing helps remove wrinkles from freshly washed clothes.", 
     {"entities": [(0, 7, "SKILLS"), (11, 18, "SERVICE"), (22, 28, "SPECIALIZATION")]}),
    ("Ironing of cloth ensures garments look neat and professional.", 
     {"entities": [(0, 15, "SKILLS"), (19, 26, "SERVICE"), (30, 34, "SPECIALIZATION")]}),
    ("Ironing of clothes prevents creases and maintains fabric shape.", 
     {"entities": [(0, 16, "SKILLS"), (20, 27, "SERVICE"), (31, 37, "SPECIALIZATION")]}),
    ("Ironed a cloth before folding it into the wardrobe.", 
     {"entities": [(0, 12, "SKILLS"), (16, 23, "SERVICE"), (27, 31, "SPECIALIZATION")]}),
    ("Ironed a clothes to remove wrinkles and make them presentable.", 
     {"entities": [(0, 13, "SKILLS"), (17, 24, "SERVICE"), (28, 34, "SPECIALIZATION")]}),
    ("Ironed cloth carefully to avoid damaging delicate fabrics.", 
     {"entities": [(0, 11, "SKILLS"), (15, 22, "SERVICE"), (26, 32, "SPECIALIZATION")]}),
    ("Ironed clothes thoroughly for a crisp, professional appearance.", 
     {"entities": [(0, 13, "SKILLS"), (17, 24, "SERVICE"), (28, 34, "SPECIALIZATION")]}),
    #stain removal
    ("Stain removal is essential to keep carpets and fabrics looking clean.", 
     {"entities": [(0, 13, "SKILLS"), (17, 24, "SERVICE"), (28, 38, "SPECIALIZATION")]}),
    ("Removing stain from upholstery requires proper cleaning techniques.", 
     {"entities": [(0, 14, "SKILLS"), (18, 25, "SERVICE"), (29, 39, "SPECIALIZATION")]}),
    ("Removing of stains from curtains keeps them bright and fresh.", 
     {"entities": [(0, 17, "SKILLS"), (21, 28, "SERVICE"), (32, 40, "SPECIALIZATION")]}),
    ("Removing of stain from delicate fabrics should be done carefully.", 
     {"entities": [(0, 16, "SKILLS"), (20, 27, "SERVICE"), (31, 39, "SPECIALIZATION")]}),
    ("Removed a stain from the carpet using a gentle cleaning solution.", 
     {"entities": [(0, 13, "SKILLS"), (17, 24, "SERVICE"), (28, 34, "SPECIALIZATION")]}),
    ("Removed stains from the sofa before the guests arrived.", 
     {"entities": [(0, 13, "SKILLS"), (17, 24, "SERVICE"), (28, 32, "SPECIALIZATION")]}),
    ("Removed stain from the curtain without damaging the fabric.", 
     {"entities": [(0, 12, "SKILLS"), (16, 23, "SERVICE"), (27, 34, "SPECIALIZATION")]}),
    ("Removed a stains from delicate upholstery carefully.", 
     {"entities": [(0, 15, "SKILLS"), (19, 26, "SERVICE"), (30, 41, "SPECIALIZATION")]}),

]
